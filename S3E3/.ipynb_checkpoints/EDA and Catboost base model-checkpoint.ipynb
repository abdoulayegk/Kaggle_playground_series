# %% [markdown]
# # Importing libraries

# %%
import warnings

import matplotlib.pyplot as plt
import missingno as mn
import numpy as np
import pandas as pd
import plotly.express as px
from plotly.offline import download_plotlyjs, init_notebook_mode, iplot, plot
from tqdm import tqdm

init_notebook_mode(connected=True)
import seaborn as sns
from catboost import CatBoostClassifier
from lightgbm import LGBMClassifier
from sklearn import metrics
from sklearn.model_selection import KFold, StratifiedKFold
from sklearn.preprocessing import LabelEncoder, OneHotEncoder

pd.set_option("display.max_columns", 50)
warnings.filterwarnings("ignore")
# warnings.filterwarnings("ignore", category="FutureWarning")
# warnings.filterwarnings("ignore", category="DeprecationWarning")
# warnings.filterwarnings("ignore", category="UserWarning")

# Color Palette
custom_colors = ["#7400ff", "#a788e4", "#d216d2", "#ffb500", "#36c9dd"]
sns.palplot(sns.color_palette(custom_colors))

# Set Style
sns.set_style("whitegrid")
sns.despine(left=True, bottom=True)

# Set tick size
plt.rc("xtick", labelsize=12)
plt.rc("ytick", labelsize=12)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.12.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# ## Loading the data

# %%
train = pd.read_csv("train.csv").drop("id", axis=1)
test = pd.read_csv("test.csv").drop("id", axis=1)
ss = pd.read_csv("sample_submission.csv")

# %%
train.head()
# Out:
#    Age     BusinessTravel  DailyRate              Department  \
# 0   36  Travel_Frequently        599  Research & Development
# 1   35      Travel_Rarely        921                   Sales
# 2   32      Travel_Rarely        718                   Sales
# 3   38      Travel_Rarely       1488  Research & Development
# 4   50      Travel_Rarely       1017  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  \
# 0                24          3        Medical              1
# 1                 8          3          Other              1
# 2                26          3      Marketing              1
# 3                 2          3        Medical              1
# 4                 5          4        Medical              1
#
#    EnvironmentSatisfaction  Gender  HourlyRate  JobInvolvement  JobLevel  \
# 0                        4    Male          42               3         1
# 1                        1    Male          46               3         1
# 2                        3    Male          80               3         2
# 3                        3  Female          40               3         2
# 4                        2  Female          37               3         5
#
#                      JobRole  JobSatisfaction MaritalStatus  MonthlyIncome  \
# 0      Laboratory Technician                4       Married           2596
# 1       Sales Representative                1       Married           2899
# 2            Sales Executive                4      Divorced           4627
# 3  Healthcare Representative                1       Married           5347
# 4                    Manager                1        Single          19033
#
#    MonthlyRate  NumCompaniesWorked Over18 OverTime  PercentSalaryHike  \
# 0         5099                   1      Y      Yes                 13
# 1        10778                   1      Y       No                 17
# 2        16495                   0      Y       No                 17
# 3        13384                   3      Y       No                 14
# 4        19805                   1      Y      Yes                 13
#
#    PerformanceRating  RelationshipSatisfaction  StandardHours  \
# 0                  3                         2             80
# 1                  3                         4             80
# 2                  3                         4             80
# 3                  3                         3             80
# 4                  3                         3             80
#
#    StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  \
# 0                 1                 10                      2
# 1                 1                  4                      3
# 2                 2                  4                      3
# 3                 0                 15                      1
# 4                 0                 31                      0
#
#    WorkLifeBalance  YearsAtCompany  YearsInCurrentRole  \
# 0                3              10                   0
# 1                3               4                   2
# 2                3               3                   2
# 3                1               6                   0
# 4                3              31                  14
#
#    YearsSinceLastPromotion  YearsWithCurrManager  Attrition
# 0                        7                     8          0
# 1                        0                     3          0
# 2                        1                     2          0
# 3                        0                     2          0
# 4                        4                    10          1

# %%
test.head()
# Out:
#    Age     BusinessTravel  DailyRate              Department  \
# 0   19         Non-Travel        992  Research & Development
# 1   45      Travel_Rarely       1136                   Sales
# 2   37      Travel_Rarely        155  Research & Development
# 3   32      Travel_Rarely        688  Research & Development
# 4   29  Travel_Frequently        464  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  \
# 0                 1          1        Medical              1
# 1                 4          4      Marketing              1
# 2                13          3  Life Sciences              1
# 3                 1          4  Life Sciences              1
# 4                 9          1  Life Sciences              1
#
#    EnvironmentSatisfaction Gender  HourlyRate  JobInvolvement  JobLevel  \
# 0                        4   Male          43               3         1
# 1                        3   Male          67               3         2
# 2                        4   Male          41               3         1
# 3                        3   Male          89               2         2
# 4                        3   Male          79               3         1
#
#                      JobRole  JobSatisfaction MaritalStatus  MonthlyIncome  \
# 0      Laboratory Technician                3        Single           2318
# 1            Sales Executive                1      Divorced           5486
# 2         Research Scientist                4      Divorced           2741
# 3  Healthcare Representative                3        Single           5228
# 4      Laboratory Technician                4        Single           1223
#
#    MonthlyRate  NumCompaniesWorked Over18 OverTime  PercentSalaryHike  \
# 0        17778                   1      Y       No                 12
# 1        12421                   6      Y      Yes                 12
# 2        23577                   4      Y      Yes                 13
# 3        20364                   1      Y       No                 13
# 4        15178                   1      Y       No                 14
#
#    PerformanceRating  RelationshipSatisfaction  StandardHours  \
# 0                  3                         4             80
# 1                  3                         3             80
# 2                  3                         2             80
# 3                  3                         3             80
# 4                  3                         1             80
#
#    StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  \
# 0                 0                  1                      2
# 1                 1                  7                      3
# 2                 2                 13                      2
# 3                 0                 14                      2
# 4                 0                  1                      5
#
#    WorkLifeBalance  YearsAtCompany  YearsInCurrentRole  \
# 0                2               1                   0
# 1                3               2                   2
# 2                2               7                   7
# 3                2              14                  10
# 4                3               1                   0
#
#    YearsSinceLastPromotion  YearsWithCurrManager
# 0                        0                     0
# 1                        2                     2
# 2                        1                     7
# 3                       11                     8
# 4                        0                     0

# %%
ss.head()
# Out:
#      id  Attrition
# 0  1677   0.119261
# 1  1678   0.119261
# 2  1679   0.119261
# 3  1680   0.119261
# 4  1681   0.119261

# %%
# Looking at the size of the data
train.shape, test.shape
# Out:
# ((1677, 34), (1119, 33))

# %%
train.describe().T.style.bar(
    subset=["mean"], color=custom_colors[1]
).background_gradient(subset=["std"], cmap="Reds").background_gradient(
    subset=["50%"], cmap="coolwarm"
)
# Out:
# <style type="text/css">
# #T_35453_row0_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #a788e4 0.2%, transparent 0.2%);
# }
# #T_35453_row0_col2, #T_35453_row2_col2, #T_35453_row3_col2, #T_35453_row4_col2, #T_35453_row5_col2, #T_35453_row6_col2, #T_35453_row7_col2, #T_35453_row8_col2, #T_35453_row9_col2, #T_35453_row12_col2, #T_35453_row13_col2, #T_35453_row14_col2, #T_35453_row15_col2, #T_35453_row16_col2, #T_35453_row17_col2, #T_35453_row18_col2, #T_35453_row19_col2, #T_35453_row20_col2, #T_35453_row21_col2, #T_35453_row22_col2, #T_35453_row23_col2, #T_35453_row24_col2, #T_35453_row25_col2 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# #T_35453_row0_col5, #T_35453_row2_col5, #T_35453_row3_col5, #T_35453_row4_col5, #T_35453_row5_col5, #T_35453_row7_col5, #T_35453_row8_col5, #T_35453_row9_col5, #T_35453_row12_col5, #T_35453_row13_col5, #T_35453_row14_col5, #T_35453_row15_col5, #T_35453_row17_col5, #T_35453_row18_col5, #T_35453_row19_col5, #T_35453_row20_col5, #T_35453_row21_col5, #T_35453_row22_col5, #T_35453_row23_col5, #T_35453_row24_col5, #T_35453_row25_col5 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_35453_row1_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #a788e4 6.0%, transparent 6.0%);
# }
# #T_35453_row1_col2 {
#   background-color: #ffece4;
#   color: #000000;
# }
# #T_35453_row1_col5 {
#   background-color: #4b64d5;
#   color: #f1f1f1;
# }
# #T_35453_row2_col1, #T_35453_row13_col1, #T_35453_row18_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #a788e4 0.1%, transparent 0.1%);
# }
# #T_35453_row3_col1, #T_35453_row4_col1, #T_35453_row5_col1, #T_35453_row7_col1, #T_35453_row8_col1, #T_35453_row9_col1, #T_35453_row12_col1, #T_35453_row14_col1, #T_35453_row15_col1, #T_35453_row17_col1, #T_35453_row19_col1, #T_35453_row20_col1, #T_35453_row21_col1, #T_35453_row22_col1, #T_35453_row23_col1, #T_35453_row24_col1, #T_35453_row25_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #a788e4 0.0%, transparent 0.0%);
# }
# #T_35453_row6_col1, #T_35453_row16_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #a788e4 0.5%, transparent 0.5%);
# }
# #T_35453_row6_col5, #T_35453_row16_col5 {
#   background-color: #3c4ec2;
#   color: #f1f1f1;
# }
# #T_35453_row10_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #a788e4 42.0%, transparent 42.0%);
# }
# #T_35453_row10_col2 {
#   background-color: #ec382b;
#   color: #f1f1f1;
# }
# #T_35453_row10_col5 {
#   background-color: #a3c2fe;
#   color: #000000;
# }
# #T_35453_row11_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #a788e4 100.0%, transparent 100.0%);
# }
# #T_35453_row11_col2 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_35453_row11_col5 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_35453">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_35453_level0_col0" class="col_heading level0 col0" >count</th>
#       <th id="T_35453_level0_col1" class="col_heading level0 col1" >mean</th>
#       <th id="T_35453_level0_col2" class="col_heading level0 col2" >std</th>
#       <th id="T_35453_level0_col3" class="col_heading level0 col3" >min</th>
#       <th id="T_35453_level0_col4" class="col_heading level0 col4" >25%</th>
#       <th id="T_35453_level0_col5" class="col_heading level0 col5" >50%</th>
#       <th id="T_35453_level0_col6" class="col_heading level0 col6" >75%</th>
#       <th id="T_35453_level0_col7" class="col_heading level0 col7" >max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_35453_level0_row0" class="row_heading level0 row0" >Age</th>
#       <td id="T_35453_row0_col0" class="data row0 col0" >1677.000000</td>
#       <td id="T_35453_row0_col1" class="data row0 col1" >36.036971</td>
#       <td id="T_35453_row0_col2" class="data row0 col2" >8.507112</td>
#       <td id="T_35453_row0_col3" class="data row0 col3" >18.000000</td>
#       <td id="T_35453_row0_col4" class="data row0 col4" >30.000000</td>
#       <td id="T_35453_row0_col5" class="data row0 col5" >35.000000</td>
#       <td id="T_35453_row0_col6" class="data row0 col6" >41.000000</td>
#       <td id="T_35453_row0_col7" class="data row0 col7" >60.000000</td>
#     </tr>
#     <tr>
#       <th id="T_35453_level0_row1" class="row_heading level0 row1" >DailyRate</th>
#       <td id="T_35453_row1_col0" class="data row1 col0" >1677.000000</td>
#       <td id="T_35453_row1_col1" class="data row1 col1" >892.749553</td>
#       <td id="T_35453_row1_col2" class="data row1 col2" >374.496259</td>
#       <td id="T_35453_row1_col3" class="data row1 col3" >107.000000</td>
#       <td id="T_35453_row1_col4" class="data row1 col4" >589.000000</td>
#       <td id="T_35453_row1_col5" class="data row1 col5" >890.000000</td>
#       <td id="T_35453_row1_col6" class="data row1 col6" >1223.000000</td>
#       <td id="T_35453_row1_col7" class="data row1 col7" >3921.000000</td>
#     </tr>
#     <tr>
#       <th id="T_35453_level0_row2" class="row_heading level0 row2" >DistanceFromHome</th>
#       <td id="T_35453_row2_col0" class="data row2 col0" >1677.000000</td>
#       <td id="T_35453_row2_col1" class="data row2 col1" >8.683959</td>
#       <td id="T_35453_row2_col2" class="data row2 col2" >7.826143</td>
#       <td id="T_35453_row2_col3" class="data row2 col3" >1.000000</td>
#       <td id="T_35453_row2_col4" class="data row2 col4" >2.000000</td>
#       <td id="T_35453_row2_col5" class="data row2 col5" >7.000000</td>
#       <td id="T_35453_row2_col6" class="data row2 col6" >12.000000</td>
#       <td id="T_35453_row2_col7" class="data row2 col7" >29.000000</td>
#     </tr>
#     <tr>
#       <th id="T_35453_level0_row3" class="row_heading level0 row3" >Education</th>
#       <td id="T_35453_row3_col0" class="data row3 col0" >1677.000000</td>
#       <td id="T_35453_row3_col1" class="data row3 col1" >2.937984</td>
#       <td id="T_35453_row3_col2" class="data row3 col2" >1.039078</td>
#       <td id="T_35453_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_35453_row3_col4" class="data row3 col4" >2.000000</td>
#       <td id="T_35453_row3_col5" class="data row3 col5" >3.000000</td>
#       <td id="T_35453_row3_col6" class="data row3 col6" >4.000000</td>
#       <td id="T_35453_row3_col7" class="data row3 col7" >15.000000</td>
#     </tr>
#     <tr>
#       <th id="T_35453_level0_row4" class="row_heading level0 row4" >EmployeeCount</th>
#       <td id="T_35453_row4_col0" class="data row4 col0" >1677.000000</td>
#       <td id="T_35453_row4_col1" class="data row4 col1" >1.000000</td>
#       <td id="T_35453_row4_col2" class="data row4 col2" >0.000000</td>
#       <td id="T_35453_row4_col3" class="data row4 col3" >1.000000</td>
#       <td id="T_35453_row4_col4" class="data row4 col4" >1.000000</td>
#       <td id="T_35453_row4_col5" class="data row4 col5" >1.000000</td>
#       <td id="T_35453_row4_col6" class="data row4 col6" >1.000000</td>
#       <td id="T_35453_row4_col7" class="data row4 col7" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_35453_level0_row5" class="row_heading level0 row5" >EnvironmentSatisfaction</th>
#       <td id="T_35453_row5_col0" class="data row5 col0" >1677.000000</td>
#       <td id="T_35453_row5_col1" class="data row5 col1" >2.757901</td>
#       <td id="T_35453_row5_col2" class="data row5 col2" >1.086835</td>
#       <td id="T_35453_row5_col3" class="data row5 col3" >1.000000</td>
#       <td id="T_35453_row5_col4" class="data row5 col4" >2.000000</td>
#       <td id="T_35453_row5_col5" class="data row5 col5" >3.000000</td>
#       <td id="T_35453_row5_col6" class="data row5 col6" >4.000000</td>
#       <td id="T_35453_row5_col7" class="data row5 col7" >4.000000</td>
#     </tr>
#     <tr>
#       <th id="T_35453_level0_row6" class="row_heading level0 row6" >HourlyRate</th>
#       <td id="T_35453_row6_col0" class="data row6 col0" >1677.000000</td>
#       <td id="T_35453_row6_col1" class="data row6 col1" >67.798450</td>
#       <td id="T_35453_row6_col2" class="data row6 col2" >19.435928</td>
#       <td id="T_35453_row6_col3" class="data row6 col3" >30.000000</td>
#       <td id="T_35453_row6_col4" class="data row6 col4" >51.000000</td>
#       <td id="T_

# %% [markdown]
# ### Distribution of the target variable

# %%
sns.countplot(train["Attrition"], color=custom_colors[1])
# Out:
# <AxesSubplot:ylabel='count'>

# %% [markdown]
# We can see that our data is unbalanced which mean it's a problem so we have to be care with this kind of problem.

# %%
train["Attrition"].value_counts().plot(kind="bar")
# Out:
# <AxesSubplot:>

# %%
# selecting categorical features
cat_features = [
    f for f in train.columns if f not in train.select_dtypes(include=["float", "int"])
]

# %%
cat_features
# Out:
# ['BusinessTravel',
#  'Department',
#  'EducationField',
#  'Gender',
#  'JobRole',
#  'MaritalStatus',
#  'Over18',
#  'OverTime']

# %% [markdown]
#  Now it's time to LabelEncode categorical features

# %%
for col in cat_features:
    # initialize Label encoder for each features
    le = LabelEncoder()
    # fit transform label encoder on all data
    train[col] = le.fit_transform(train[col])
    test[col] = le.fit_transform(test[col])
train.head()
# Out:
#    Age  BusinessTravel  DailyRate  Department  DistanceFromHome  Education  \
# 0   36               1        599           1                24          3
# 1   35               2        921           2                 8          3
# 2   32               2        718           2                26          3
# 3   38               2       1488           1                 2          3
# 4   50               2       1017           1                 5          4
#
#    EducationField  EmployeeCount  EnvironmentSatisfaction  Gender  HourlyRate  \
# 0               3              1                        4       1          42
# 1               4              1                        1       1          46
# 2               2              1                        3       1          80
# 3               3              1                        3       0          40
# 4               3              1                        2       0          37
#
#    JobInvolvement  JobLevel  JobRole  JobSatisfaction  MaritalStatus  \
# 0               3         1        2                4              1
# 1               3         1        8                1              1
# 2               3         2        7                4              0
# 3               3         2        0                1              1
# 4               3         5        3                1              2
#
#    MonthlyIncome  MonthlyRate  NumCompaniesWorked  Over18  OverTime  \
# 0           2596         5099                   1       0         1
# 1           2899        10778                   1       0         0
# 2           4627        16495                   0       0         0
# 3           5347        13384                   3       0         0
# 4          19033        19805                   1       0         1
#
#    PercentSalaryHike  PerformanceRating  RelationshipSatisfaction  \
# 0                 13                  3                         2
# 1                 17                  3                         4
# 2                 17                  3                         4
# 3                 14                  3                         3
# 4                 13                  3                         3
#
#    StandardHours  StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  \
# 0             80                 1                 10                      2
# 1             80                 1                  4                      3
# 2             80                 2                  4                      3
# 3             80                 0                 15                      1
# 4             80                 0                 31                      0
#
#    WorkLifeBalance  YearsAtCompany  YearsInCurrentRole  \
# 0                3              10                   0
# 1                3               4                   2
# 2                3               3                   2
# 3                1               6                   0
# 4                3              31                  14
#
#    YearsSinceLastPromotion  YearsWithCurrManager  Attrition
# 0                        7                     8          0
# 1                        0                     3          0
# 2                        1                     2          0
# 3                        0                     2          0
# 4                        4                    10          1

# %%
test.head()
# Out:
#    Age  BusinessTravel  DailyRate  Department  DistanceFromHome  Education  \
# 0   19               0        992           1                 1          1
# 1   45               2       1136           2                 4          4
# 2   37               2        155           1                13          3
# 3   32               2        688           1                 1          4
# 4   29               1        464           1                 9          1
#
#    EducationField  EmployeeCount  EnvironmentSatisfaction  Gender  HourlyRate  \
# 0               3              1                        4       1          43
# 1               2              1                        3       1          67
# 2               1              1                        4       1          41
# 3               1              1                        3       1          89
# 4               1              1                        3       1          79
#
#    JobInvolvement  JobLevel  JobRole  JobSatisfaction  MaritalStatus  \
# 0               3         1        2                3              2
# 1               3         2        7                1              0
# 2               3         1        6                4              0
# 3               2         2        0                3              2
# 4               3         1        2                4              2
#
#    MonthlyIncome  MonthlyRate  NumCompaniesWorked  Over18  OverTime  \
# 0           2318        17778                   1       0         0
# 1           5486        12421                   6       0         1
# 2           2741        23577                   4       0         1
# 3           5228        20364                   1       0         0
# 4           1223        15178                   1       0         0
#
#    PercentSalaryHike  PerformanceRating  RelationshipSatisfaction  \
# 0                 12                  3                         4
# 1                 12                  3                         3
# 2                 13                  3                         2
# 3                 13                  3                         3
# 4                 14                  3                         1
#
#    StandardHours  StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  \
# 0             80                 0                  1                      2
# 1             80                 1                  7                      3
# 2             80                 2                 13                      2
# 3             80                 0                 14                      2
# 4             80                 0                  1                      5
#
#    WorkLifeBalance  YearsAtCompany  YearsInCurrentRole  \
# 0                2               1                   0
# 1                3               2                   2
# 2                2               7                   7
# 3                2              14                  10
# 4                3               1                   0
#
#    YearsSinceLastPromotion  YearsWithCurrManager
# 0                        0                     0
# 1                        2                     2
# 2                        1                     7
# 3                       11                     8
# 4                        0                     0

# %% [markdown]
# Now we have transform categorical variables to numerical using label encoder so the next thing we are going to do is to select our X and Y variable and then build a model.

# %%
X = train.drop("Attrition", axis=1)
y = train.Attrition

# %%
X.shape, test.shape
# Out:
# ((1677, 33), (1119, 33))

# %% [markdown]
# # Modeling

# %%
params = {
    "objective": "Logloss",
    "colsample_bylevel": 0.08383650771477613,
    "depth": 11,
    "boosting_type": "Ordered",
    "bootstrap_type": "Bayesian",
    "bagging_temperature": 0.01880446878521802,
}

# %%
# %%time
kf = StratifiedKFold(n_splits=10, shuffle=True, random_state=42)

preds = []
scores = []
feature_importance_df = pd.DataFrame()

for fold, (idx_train, idx_valid) in enumerate(kf.split(X, y)):
    X_train, y_train = X.iloc[idx_train], y.iloc[idx_train]
    X_valid, y_valid = X.iloc[idx_valid], y.iloc[idx_valid]

    model = CatBoostClassifier(**params)

    model.fit(
        X_train,
        y_train,
        eval_set=[(X_valid, y_valid)],
        verbose=False,
        # early_stopping_rounds=400,
    )

    pred_valid = model.predict_proba(X_valid)[:, 1]
    fpr, tpr, _ = metrics.roc_curve(y_valid, pred_valid)
    score = metrics.auc(fpr, tpr)
    scores.append(score)

    fold_importance_df = pd.DataFrame()
    fold_importance_df["Feature"] = X.columns
    fold_importance_df["importance"] = model.feature_importances_
    fold_importance_df["fold"] = fold + 1
    feature_importance_df = pd.concat(
        [feature_importance_df, fold_importance_df], axis=0
    )

    print(f"Fold: {fold + 1} Score: {score}" "\n")
    print("||" * 40, "\n")

    test_preds = model.predict_proba(test)[:, 1]
    preds.append(test_preds)

print(f"Overall Validation Score: {np.mean(scores)}")
# Out:
# Fold: 1 Score: 0.8202702702702702
#
# ||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
#
# Fold: 2 Score: 0.7847972972972972
#
# ||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
#
# Fold: 3 Score: 0.8641891891891892
#
# ||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
#
# Fold: 4 Score: 0.9222972972972973
#
# ||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
#
# Fold: 5 Score: 0.7999999999999999
#
# ||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
#
# Fold: 6 Score: 0.8135135135135134
#
# ||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
#
# Fold: 7 Score: 0.8260135135135135
#
# ||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
#
# Fold: 8 Score: 0.7959183673469388
#
# ||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
#
# Fold: 9 Score: 0.9193877551020408
#
# ||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
#
# Fold: 10 Score: 0.8500000000000001
#
# ||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
#
# Overall Validation Score: 0.8396387203530061
# CPU times: user 4min 32s, sys: 53.6 s, total: 5min 26s
# Wall time: 1min 40s

# %%
cols = (
    feature_importance_df[["Feature", "importance"]]
    .groupby("Feature")
    .mean()
    .sort_values(by="importance", ascending=False)[:107]
    .index
)
best_features = feature_importance_df.loc[feature_importance_df.Feature.isin(cols)]

plt.figure(figsize=(14, 28))
sns.barplot(
    x="importance",
    y="Feature",
    data=best_features.sort_values(by="importance", ascending=False),
)
plt.title("Features importance (averaged/folds)")
plt.tight_layout()
plt.savefig("FI.png")

# %%
ss.head()
# Out:
#      id  Attrition
# 0  1677   0.119261
# 1  1678   0.119261
# 2  1679   0.119261
# 3  1680   0.119261
# 4  1681   0.119261

# %%
predictions = np.mean(np.column_stack(preds), axis=1)

ss["Attrition"] = predictions
ss.to_csv("./cb.csv", index=False)
ss.head()
# Out:
#      id  Attrition
# 0  1677   0.146111
# 1  1678   0.040698
# 2  1679   0.035731
# 3  1680   0.060920
# 4  1681   0.471611

# %%
kajlkjl
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 kajlkjl
#
# NameError: name 'kajlkjl' is not defined

# %%
import catboost as cb
import optuna
from optuna.integration import CatBoostPruningCallback
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split


def objective(trial: optuna.Trial) -> float:
    train_x, valid_x, train_y, valid_y = train_test_split(X, y, test_size=0.25)

    param = {
        "objective": trial.suggest_categorical(
            "objective", ["Logloss", "CrossEntropy"]
        ),
        "colsample_bylevel": trial.suggest_float(
            "colsample_bylevel", 0.01, 0.1, log=True
        ),
        "depth": trial.suggest_int("depth", 1, 12),
        "boosting_type": trial.suggest_categorical(
            "boosting_type", ["Ordered", "Plain"]
        ),
        "bootstrap_type": trial.suggest_categorical(
            "bootstrap_type", ["Bayesian", "Bernoulli", "MVS"]
        ),
        "used_ram_limit": "3gb",
        "eval_metric": "Accuracy",
    }

    if param["bootstrap_type"] == "Bayesian":
        param["bagging_temperature"] = trial.suggest_float("bagging_temperature", 0, 10)
    elif param["bootstrap_type"] == "Bernoulli":
        param["subsample"] = trial.suggest_float("subsample", 0.1, 1, log=True)

    gbm = cb.CatBoostClassifier(**param)

    pruning_callback = CatBoostPruningCallback(trial, "Accuracy")
    gbm.fit(
        train_x,
        train_y,
        eval_set=[(valid_x, valid_y)],
        verbose=0,
        early_stopping_rounds=100,
        callbacks=[pruning_callback],
    )

    # evoke pruning manually.
    pruning_callback.check_pruned()

    preds = gbm.predict(valid_x)
    pred_labels = np.rint(preds)
    accuracy = accuracy_score(valid_y, pred_labels)

    return accuracy


if __name__ == "__main__":
    study = optuna.create_study(
        pruner=optuna.pruners.MedianPruner(n_warmup_steps=5), direction="maximize"
    )
    study.optimize(objective, n_trials=100, timeout=600)

    print("Number of finished trials: {}".format(len(study.trials)))

    print("Best trial:")
    trial = study.best_trial

    print("  Value: {}".format(trial.value))

    print("  Params: ")
    for key, value in trial.params.items():
        print("    {}: {}".format(key, value))
