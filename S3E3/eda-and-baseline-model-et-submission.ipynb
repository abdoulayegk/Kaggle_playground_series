# %% [markdown]
# # Importing libraries

# %%
import warnings

import matplotlib.pyplot as plt
import missingno as mn
import numpy as np
import pandas as pd
import plotly.express as px
from plotly.offline import download_plotlyjs, init_notebook_mode, iplot, plot
from tqdm import tqdm

init_notebook_mode(connected=True)
import seaborn as sns
from catboost import CatBoostClassifier
from lightgbm import LGBMClassifier
from sklearn import metrics
from sklearn.model_selection import (
    KFold,
    RepeatedKFold,
    RepeatedStratifiedKFold,
    StratifiedKFold,
    StratifiedShuffleSplit,
)
from sklearn.preprocessing import LabelEncoder, OneHotEncoder

pd.set_option("display.max_columns", 50)
warnings.filterwarnings("ignore")
# warnings.filterwarnings("ignore", category="FutureWarning")
# warnings.filterwarnings("ignore", category="DeprecationWarning")
# warnings.filterwarnings("ignore", category="UserWarning")

# Color Palette
custom_colors = ["#7400ff", "#a788e4", "#d216d2", "#ffb500", "#36c9dd"]
sns.palplot(sns.color_palette(custom_colors))

# Set Style
sns.set_style("whitegrid")
sns.despine(left=True, bottom=True)

# Set tick size
plt.rc("xtick", labelsize=12)
plt.rc("ytick", labelsize=12)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.12.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# ## Loading the data

# %%
train = pd.read_csv("train.csv").drop("id", axis=1)
test = pd.read_csv("test.csv").drop("id", axis=1)
ss = pd.read_csv("sample_submission.csv")

# %%
train.head()
# Out:
#    Age     BusinessTravel  DailyRate              Department  \
# 0   36  Travel_Frequently        599  Research & Development
# 1   35      Travel_Rarely        921                   Sales
# 2   32      Travel_Rarely        718                   Sales
# 3   38      Travel_Rarely       1488  Research & Development
# 4   50      Travel_Rarely       1017  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  \
# 0                24          3        Medical              1
# 1                 8          3          Other              1
# 2                26          3      Marketing              1
# 3                 2          3        Medical              1
# 4                 5          4        Medical              1
#
#    EnvironmentSatisfaction  Gender  HourlyRate  JobInvolvement  JobLevel  \
# 0                        4    Male          42               3         1
# 1                        1    Male          46               3         1
# 2                        3    Male          80               3         2
# 3                        3  Female          40               3         2
# 4                        2  Female          37               3         5
#
#                      JobRole  JobSatisfaction MaritalStatus  MonthlyIncome  \
# 0      Laboratory Technician                4       Married           2596
# 1       Sales Representative                1       Married           2899
# 2            Sales Executive                4      Divorced           4627
# 3  Healthcare Representative                1       Married           5347
# 4                    Manager                1        Single          19033
#
#    MonthlyRate  NumCompaniesWorked Over18 OverTime  PercentSalaryHike  \
# 0         5099                   1      Y      Yes                 13
# 1        10778                   1      Y       No                 17
# 2        16495                   0      Y       No                 17
# 3        13384                   3      Y       No                 14
# 4        19805                   1      Y      Yes                 13
#
#    PerformanceRating  RelationshipSatisfaction  StandardHours  \
# 0                  3                         2             80
# 1                  3                         4             80
# 2                  3                         4             80
# 3                  3                         3             80
# 4                  3                         3             80
#
#    StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  \
# 0                 1                 10                      2
# 1                 1                  4                      3
# 2                 2                  4                      3
# 3                 0                 15                      1
# 4                 0                 31                      0
#
#    WorkLifeBalance  YearsAtCompany  YearsInCurrentRole  \
# 0                3              10                   0
# 1                3               4                   2
# 2                3               3                   2
# 3                1               6                   0
# 4                3              31                  14
#
#    YearsSinceLastPromotion  YearsWithCurrManager  Attrition
# 0                        7                     8          0
# 1                        0                     3          0
# 2                        1                     2          0
# 3                        0                     2          0
# 4                        4                    10          1

# %%
test.head()
# Out:
#    Age     BusinessTravel  DailyRate              Department  \
# 0   19         Non-Travel        992  Research & Development
# 1   45      Travel_Rarely       1136                   Sales
# 2   37      Travel_Rarely        155  Research & Development
# 3   32      Travel_Rarely        688  Research & Development
# 4   29  Travel_Frequently        464  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  \
# 0                 1          1        Medical              1
# 1                 4          4      Marketing              1
# 2                13          3  Life Sciences              1
# 3                 1          4  Life Sciences              1
# 4                 9          1  Life Sciences              1
#
#    EnvironmentSatisfaction Gender  HourlyRate  JobInvolvement  JobLevel  \
# 0                        4   Male          43               3         1
# 1                        3   Male          67               3         2
# 2                        4   Male          41               3         1
# 3                        3   Male          89               2         2
# 4                        3   Male          79               3         1
#
#                      JobRole  JobSatisfaction MaritalStatus  MonthlyIncome  \
# 0      Laboratory Technician                3        Single           2318
# 1            Sales Executive                1      Divorced           5486
# 2         Research Scientist                4      Divorced           2741
# 3  Healthcare Representative                3        Single           5228
# 4      Laboratory Technician                4        Single           1223
#
#    MonthlyRate  NumCompaniesWorked Over18 OverTime  PercentSalaryHike  \
# 0        17778                   1      Y       No                 12
# 1        12421                   6      Y      Yes                 12
# 2        23577                   4      Y      Yes                 13
# 3        20364                   1      Y       No                 13
# 4        15178                   1      Y       No                 14
#
#    PerformanceRating  RelationshipSatisfaction  StandardHours  \
# 0                  3                         4             80
# 1                  3                         3             80
# 2                  3                         2             80
# 3                  3                         3             80
# 4                  3                         1             80
#
#    StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  \
# 0                 0                  1                      2
# 1                 1                  7                      3
# 2                 2                 13                      2
# 3                 0                 14                      2
# 4                 0                  1                      5
#
#    WorkLifeBalance  YearsAtCompany  YearsInCurrentRole  \
# 0                2               1                   0
# 1                3               2                   2
# 2                2               7                   7
# 3                2              14                  10
# 4                3               1                   0
#
#    YearsSinceLastPromotion  YearsWithCurrManager
# 0                        0                     0
# 1                        2                     2
# 2                        1                     7
# 3                       11                     8
# 4                        0                     0

# %%
ss.head()
# Out:
#      id  Attrition
# 0  1677   0.119261
# 1  1678   0.119261
# 2  1679   0.119261
# 3  1680   0.119261
# 4  1681   0.119261

# %%
# Looking at the size of the data
train.shape, test.shape
# Out:
# ((1677, 34), (1119, 33))

# %%
train.describe().T.style.bar(
    subset=["mean"], color=custom_colors[1]
).background_gradient(subset=["std"], cmap="Reds").background_gradient(
    subset=["50%"], cmap="coolwarm"
)
# Out:
# <style type="text/css">
# #T_2e846_row0_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #a788e4 0.2%, transparent 0.2%);
# }
# #T_2e846_row0_col2, #T_2e846_row2_col2, #T_2e846_row3_col2, #T_2e846_row4_col2, #T_2e846_row5_col2, #T_2e846_row6_col2, #T_2e846_row7_col2, #T_2e846_row8_col2, #T_2e846_row9_col2, #T_2e846_row12_col2, #T_2e846_row13_col2, #T_2e846_row14_col2, #T_2e846_row15_col2, #T_2e846_row16_col2, #T_2e846_row17_col2, #T_2e846_row18_col2, #T_2e846_row19_col2, #T_2e846_row20_col2, #T_2e846_row21_col2, #T_2e846_row22_col2, #T_2e846_row23_col2, #T_2e846_row24_col2, #T_2e846_row25_col2 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# #T_2e846_row0_col5, #T_2e846_row2_col5, #T_2e846_row3_col5, #T_2e846_row4_col5, #T_2e846_row5_col5, #T_2e846_row7_col5, #T_2e846_row8_col5, #T_2e846_row9_col5, #T_2e846_row12_col5, #T_2e846_row13_col5, #T_2e846_row14_col5, #T_2e846_row15_col5, #T_2e846_row17_col5, #T_2e846_row18_col5, #T_2e846_row19_col5, #T_2e846_row20_col5, #T_2e846_row21_col5, #T_2e846_row22_col5, #T_2e846_row23_col5, #T_2e846_row24_col5, #T_2e846_row25_col5 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_2e846_row1_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #a788e4 6.0%, transparent 6.0%);
# }
# #T_2e846_row1_col2 {
#   background-color: #ffece4;
#   color: #000000;
# }
# #T_2e846_row1_col5 {
#   background-color: #4b64d5;
#   color: #f1f1f1;
# }
# #T_2e846_row2_col1, #T_2e846_row13_col1, #T_2e846_row18_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #a788e4 0.1%, transparent 0.1%);
# }
# #T_2e846_row3_col1, #T_2e846_row4_col1, #T_2e846_row5_col1, #T_2e846_row7_col1, #T_2e846_row8_col1, #T_2e846_row9_col1, #T_2e846_row12_col1, #T_2e846_row14_col1, #T_2e846_row15_col1, #T_2e846_row17_col1, #T_2e846_row19_col1, #T_2e846_row20_col1, #T_2e846_row21_col1, #T_2e846_row22_col1, #T_2e846_row23_col1, #T_2e846_row24_col1, #T_2e846_row25_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #a788e4 0.0%, transparent 0.0%);
# }
# #T_2e846_row6_col1, #T_2e846_row16_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #a788e4 0.5%, transparent 0.5%);
# }
# #T_2e846_row6_col5, #T_2e846_row16_col5 {
#   background-color: #3c4ec2;
#   color: #f1f1f1;
# }
# #T_2e846_row10_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #a788e4 42.0%, transparent 42.0%);
# }
# #T_2e846_row10_col2 {
#   background-color: #ec382b;
#   color: #f1f1f1;
# }
# #T_2e846_row10_col5 {
#   background-color: #a3c2fe;
#   color: #000000;
# }
# #T_2e846_row11_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #a788e4 100.0%, transparent 100.0%);
# }
# #T_2e846_row11_col2 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_2e846_row11_col5 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_2e846">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2e846_level0_col0" class="col_heading level0 col0" >count</th>
#       <th id="T_2e846_level0_col1" class="col_heading level0 col1" >mean</th>
#       <th id="T_2e846_level0_col2" class="col_heading level0 col2" >std</th>
#       <th id="T_2e846_level0_col3" class="col_heading level0 col3" >min</th>
#       <th id="T_2e846_level0_col4" class="col_heading level0 col4" >25%</th>
#       <th id="T_2e846_level0_col5" class="col_heading level0 col5" >50%</th>
#       <th id="T_2e846_level0_col6" class="col_heading level0 col6" >75%</th>
#       <th id="T_2e846_level0_col7" class="col_heading level0 col7" >max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2e846_level0_row0" class="row_heading level0 row0" >Age</th>
#       <td id="T_2e846_row0_col0" class="data row0 col0" >1677.000000</td>
#       <td id="T_2e846_row0_col1" class="data row0 col1" >36.036971</td>
#       <td id="T_2e846_row0_col2" class="data row0 col2" >8.507112</td>
#       <td id="T_2e846_row0_col3" class="data row0 col3" >18.000000</td>
#       <td id="T_2e846_row0_col4" class="data row0 col4" >30.000000</td>
#       <td id="T_2e846_row0_col5" class="data row0 col5" >35.000000</td>
#       <td id="T_2e846_row0_col6" class="data row0 col6" >41.000000</td>
#       <td id="T_2e846_row0_col7" class="data row0 col7" >60.000000</td>
#     </tr>
#     <tr>
#       <th id="T_2e846_level0_row1" class="row_heading level0 row1" >DailyRate</th>
#       <td id="T_2e846_row1_col0" class="data row1 col0" >1677.000000</td>
#       <td id="T_2e846_row1_col1" class="data row1 col1" >892.749553</td>
#       <td id="T_2e846_row1_col2" class="data row1 col2" >374.496259</td>
#       <td id="T_2e846_row1_col3" class="data row1 col3" >107.000000</td>
#       <td id="T_2e846_row1_col4" class="data row1 col4" >589.000000</td>
#       <td id="T_2e846_row1_col5" class="data row1 col5" >890.000000</td>
#       <td id="T_2e846_row1_col6" class="data row1 col6" >1223.000000</td>
#       <td id="T_2e846_row1_col7" class="data row1 col7" >3921.000000</td>
#     </tr>
#     <tr>
#       <th id="T_2e846_level0_row2" class="row_heading level0 row2" >DistanceFromHome</th>
#       <td id="T_2e846_row2_col0" class="data row2 col0" >1677.000000</td>
#       <td id="T_2e846_row2_col1" class="data row2 col1" >8.683959</td>
#       <td id="T_2e846_row2_col2" class="data row2 col2" >7.826143</td>
#       <td id="T_2e846_row2_col3" class="data row2 col3" >1.000000</td>
#       <td id="T_2e846_row2_col4" class="data row2 col4" >2.000000</td>
#       <td id="T_2e846_row2_col5" class="data row2 col5" >7.000000</td>
#       <td id="T_2e846_row2_col6" class="data row2 col6" >12.000000</td>
#       <td id="T_2e846_row2_col7" class="data row2 col7" >29.000000</td>
#     </tr>
#     <tr>
#       <th id="T_2e846_level0_row3" class="row_heading level0 row3" >Education</th>
#       <td id="T_2e846_row3_col0" class="data row3 col0" >1677.000000</td>
#       <td id="T_2e846_row3_col1" class="data row3 col1" >2.937984</td>
#       <td id="T_2e846_row3_col2" class="data row3 col2" >1.039078</td>
#       <td id="T_2e846_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_2e846_row3_col4" class="data row3 col4" >2.000000</td>
#       <td id="T_2e846_row3_col5" class="data row3 col5" >3.000000</td>
#       <td id="T_2e846_row3_col6" class="data row3 col6" >4.000000</td>
#       <td id="T_2e846_row3_col7" class="data row3 col7" >15.000000</td>
#     </tr>
#     <tr>
#       <th id="T_2e846_level0_row4" class="row_heading level0 row4" >EmployeeCount</th>
#       <td id="T_2e846_row4_col0" class="data row4 col0" >1677.000000</td>
#       <td id="T_2e846_row4_col1" class="data row4 col1" >1.000000</td>
#       <td id="T_2e846_row4_col2" class="data row4 col2" >0.000000</td>
#       <td id="T_2e846_row4_col3" class="data row4 col3" >1.000000</td>
#       <td id="T_2e846_row4_col4" class="data row4 col4" >1.000000</td>
#       <td id="T_2e846_row4_col5" class="data row4 col5" >1.000000</td>
#       <td id="T_2e846_row4_col6" class="data row4 col6" >1.000000</td>
#       <td id="T_2e846_row4_col7" class="data row4 col7" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_2e846_level0_row5" class="row_heading level0 row5" >EnvironmentSatisfaction</th>
#       <td id="T_2e846_row5_col0" class="data row5 col0" >1677.000000</td>
#       <td id="T_2e846_row5_col1" class="data row5 col1" >2.757901</td>
#       <td id="T_2e846_row5_col2" class="data row5 col2" >1.086835</td>
#       <td id="T_2e846_row5_col3" class="data row5 col3" >1.000000</td>
#       <td id="T_2e846_row5_col4" class="data row5 col4" >2.000000</td>
#       <td id="T_2e846_row5_col5" class="data row5 col5" >3.000000</td>
#       <td id="T_2e846_row5_col6" class="data row5 col6" >4.000000</td>
#       <td id="T_2e846_row5_col7" class="data row5 col7" >4.000000</td>
#     </tr>
#     <tr>
#       <th id="T_2e846_level0_row6" class="row_heading level0 row6" >HourlyRate</th>
#       <td id="T_2e846_row6_col0" class="data row6 col0" >1677.000000</td>
#       <td id="T_2e846_row6_col1" class="data row6 col1" >67.798450</td>
#       <td id="T_2e846_row6_col2" class="data row6 col2" >19.435928</td>
#       <td id="T_2e846_row6_col3" class="data row6 col3" >30.000000</td>
#       <td id="T_2e846_row6_col4" class="data row6 col4" >51.000000</td>
#       <td id="T_

# %% [markdown]
# ### Distribution of the target variable

# %%
sns.countplot(train["Attrition"], color=custom_colors[1])
# Out:
# <AxesSubplot:ylabel='count'>

# %% [markdown]
# We can see that our data is unbalanced which mean it's a problem so we have to be care with this kind of problem.

# %%
train["Attrition"].value_counts().plot(kind="bar", color=custom_colors[2])
# Out:
# <AxesSubplot:>

# %%
features = train.columns.values[27:31]
i = 0
sns.set_style("whitegrid")
plt.figure()
fig, ax = plt.subplots(10, 10, figsize=(12, 16))

for feature in features:
    i += 1
    plt.subplot(2, 2, i)
    sns.distplot(train[feature], hist=False, label="train", color=custom_colors[0])
    sns.distplot(test[feature], hist=False, label="test", color=custom_colors[2])
    plt.xlabel(feature, fontsize=9)
    locs, labels = plt.xticks()
    plt.tick_params(axis="x", which="major", labelsize=6, pad=-6)
    plt.tick_params(axis="y", which="major", labelsize=6)
plt.show();

# %%
# selecting categorical features
cat_features = [
    f for f in train.columns if f not in train.select_dtypes(include=["float", "int"])
]

# %%
cat_features
# Out:
# ['BusinessTravel',
#  'Department',
#  'EducationField',
#  'Gender',
#  'JobRole',
#  'MaritalStatus',
#  'Over18',
#  'OverTime']

# %%
# Use a for loop to create a countplot for each feature
for feature in cat_features:
    plt.figure()
    sns.countplot(x=feature, data=train, color=custom_colors[2], orient="v")
    plt.show()

# %% [markdown]
# # Features Engineering techniques

# %%
# count of BusinessTravel
train["Count_BusinessTravel"] = train["BusinessTravel"].map(
    train["BusinessTravel"].value_counts().to_dict()
)
test["Count_BusinessTravel"] = test["BusinessTravel"].map(
    test["BusinessTravel"].value_counts().to_dict()
)
# Count of Department
train["Count_Department"] = train["Department"].map(
    train["Department"].value_counts().to_dict()
)
test["Count_Department"] = test["Department"].map(
    test["Department"].value_counts().to_dict()
)

# Count of EducationField
train["Count_EducationField"] = train["EducationField"].map(
    train["EducationField"].value_counts().to_dict()
)
test["Count_EducationField"] = test["EducationField"].map(
    test["EducationField"].value_counts().to_dict()
)

# Gender Count

train["Count_Gender"] = train["Gender"].map(train["Gender"].value_counts().to_dict())
test["Count_Gender"] = test["Gender"].map(test["Gender"].value_counts().to_dict())

# JobRole Count
train["Count_JobRole"] = train["JobRole"].map(train["JobRole"].value_counts().to_dict())
test["Count_JobRole"] = test["JobRole"].map(test["JobRole"].value_counts().to_dict())

# MaritalStatus Count
train["Count_MaritalStatus"] = train["MaritalStatus"].map(
    train["MaritalStatus"].value_counts().to_dict()
)
test["Count_MaritalStatus"] = test["MaritalStatus"].map(
    test["MaritalStatus"].value_counts().to_dict()
)

# %%
train.head()
# Out:
#    Age     BusinessTravel  DailyRate              Department  \
# 0   36  Travel_Frequently        599  Research & Development
# 1   35      Travel_Rarely        921                   Sales
# 2   32      Travel_Rarely        718                   Sales
# 3   38      Travel_Rarely       1488  Research & Development
# 4   50      Travel_Rarely       1017  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  \
# 0                24          3        Medical              1
# 1                 8          3          Other              1
# 2                26          3      Marketing              1
# 3                 2          3        Medical              1
# 4                 5          4        Medical              1
#
#    EnvironmentSatisfaction  Gender  HourlyRate  JobInvolvement  JobLevel  \
# 0                        4    Male          42               3         1
# 1                        1    Male          46               3         1
# 2                        3    Male          80               3         2
# 3                        3  Female          40               3         2
# 4                        2  Female          37               3         5
#
#                      JobRole  JobSatisfaction MaritalStatus  MonthlyIncome  \
# 0      Laboratory Technician                4       Married           2596
# 1       Sales Representative                1       Married           2899
# 2            Sales Executive                4      Divorced           4627
# 3  Healthcare Representative                1       Married           5347
# 4                    Manager                1        Single          19033
#
#    MonthlyRate  NumCompaniesWorked Over18 OverTime  PercentSalaryHike  \
# 0         5099                   1      Y      Yes                 13
# 1        10778                   1      Y       No                 17
# 2        16495                   0      Y       No                 17
# 3        13384                   3      Y       No                 14
# 4        19805                   1      Y      Yes                 13
#
#    PerformanceRating  RelationshipSatisfaction  StandardHours  \
# 0                  3                         2             80
# 1                  3                         4             80
# 2                  3                         4             80
# 3                  3                         3             80
# 4                  3                         3             80
#
#    StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  \
# 0                 1                 10                      2
# 1                 1                  4                      3
# 2                 2                  4                      3
# 3                 0                 15                      1
# 4                 0                 31                      0
#
#    WorkLifeBalance  YearsAtCompany  YearsInCurrentRole  \
# 0                3              10                   0
# 1                3               4                   2
# 2                3               3                   2
# 3                1               6                   0
# 4                3              31                  14
#
#    YearsSinceLastPromotion  YearsWithCurrManager  Attrition  \
# 0                        7                     8          0
# 1                        0                     3          0
# 2                        1                     2          0
# 3                        0                     2          0
# 4                        4                    10          1
#
#    Count_BusinessTravel  Count_Department  Count_EducationField  Count_Gender  \
# 0                   261              1167                   549          1064
# 1                  1290               471                    82          1064
# 2                  1290               471                   152          1064
# 3                  1290              1167                   549           613
# 4                  1290              1167                   549           613
#
#    Count_JobRole  Count_MaritalStatus
# 0            334                  773
# 1             77                  773
# 2            355                  327
# 3            155                  773
# 4            111                  577

# %% [markdown]
# From the above graphs we can see that some features doesn't carry any imformations it has only single value so we are gonna drop those columns later on.

# %% [markdown]
#  ## Now it's time to LabelEncode categorical features

# %%
for col in cat_features:
    # initialize Label encoder for each features
    # le = LabelEncoder()
    # fit transform label encoder on all data
    train[col] = train[col].astype("category")
    test[col] = test[col].astype("category")
train.head()
# Out:
#    Age     BusinessTravel  DailyRate              Department  \
# 0   36  Travel_Frequently        599  Research & Development
# 1   35      Travel_Rarely        921                   Sales
# 2   32      Travel_Rarely        718                   Sales
# 3   38      Travel_Rarely       1488  Research & Development
# 4   50      Travel_Rarely       1017  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  \
# 0                24          3        Medical              1
# 1                 8          3          Other              1
# 2                26          3      Marketing              1
# 3                 2          3        Medical              1
# 4                 5          4        Medical              1
#
#    EnvironmentSatisfaction  Gender  HourlyRate  JobInvolvement  JobLevel  \
# 0                        4    Male          42               3         1
# 1                        1    Male          46               3         1
# 2                        3    Male          80               3         2
# 3                        3  Female          40               3         2
# 4                        2  Female          37               3         5
#
#                      JobRole  JobSatisfaction MaritalStatus  MonthlyIncome  \
# 0      Laboratory Technician                4       Married           2596
# 1       Sales Representative                1       Married           2899
# 2            Sales Executive                4      Divorced           4627
# 3  Healthcare Representative                1       Married           5347
# 4                    Manager                1        Single          19033
#
#    MonthlyRate  NumCompaniesWorked Over18 OverTime  PercentSalaryHike  \
# 0         5099                   1      Y      Yes                 13
# 1        10778                   1      Y       No                 17
# 2        16495                   0      Y       No                 17
# 3        13384                   3      Y       No                 14
# 4        19805                   1      Y      Yes                 13
#
#    PerformanceRating  RelationshipSatisfaction  StandardHours  \
# 0                  3                         2             80
# 1                  3                         4             80
# 2                  3                         4             80
# 3                  3                         3             80
# 4                  3                         3             80
#
#    StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  \
# 0                 1                 10                      2
# 1                 1                  4                      3
# 2                 2                  4                      3
# 3                 0                 15                      1
# 4                 0                 31                      0
#
#    WorkLifeBalance  YearsAtCompany  YearsInCurrentRole  \
# 0                3              10                   0
# 1                3               4                   2
# 2                3               3                   2
# 3                1               6                   0
# 4                3              31                  14
#
#    YearsSinceLastPromotion  YearsWithCurrManager  Attrition  \
# 0                        7                     8          0
# 1                        0                     3          0
# 2                        1                     2          0
# 3                        0                     2          0
# 4                        4                    10          1
#
#    Count_BusinessTravel  Count_Department  Count_EducationField  Count_Gender  \
# 0                   261              1167                   549          1064
# 1                  1290               471                    82          1064
# 2                  1290               471                   152          1064
# 3                  1290              1167                   549           613
# 4                  1290              1167                   549           613
#
#    Count_JobRole  Count_MaritalStatus
# 0            334                  773
# 1             77                  773
# 2            355                  327
# 3            155                  773
# 4            111                  577

# %%
test.head()
# Out:
#    Age     BusinessTravel  DailyRate              Department  \
# 0   19         Non-Travel        992  Research & Development
# 1   45      Travel_Rarely       1136                   Sales
# 2   37      Travel_Rarely        155  Research & Development
# 3   32      Travel_Rarely        688  Research & Development
# 4   29  Travel_Frequently        464  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  \
# 0                 1          1        Medical              1
# 1                 4          4      Marketing              1
# 2                13          3  Life Sciences              1
# 3                 1          4  Life Sciences              1
# 4                 9          1  Life Sciences              1
#
#    EnvironmentSatisfaction Gender  HourlyRate  JobInvolvement  JobLevel  \
# 0                        4   Male          43               3         1
# 1                        3   Male          67               3         2
# 2                        4   Male          41               3         1
# 3                        3   Male          89               2         2
# 4                        3   Male          79               3         1
#
#                      JobRole  JobSatisfaction MaritalStatus  MonthlyIncome  \
# 0      Laboratory Technician                3        Single           2318
# 1            Sales Executive                1      Divorced           5486
# 2         Research Scientist                4      Divorced           2741
# 3  Healthcare Representative                3        Single           5228
# 4      Laboratory Technician                4        Single           1223
#
#    MonthlyRate  NumCompaniesWorked Over18 OverTime  PercentSalaryHike  \
# 0        17778                   1      Y       No                 12
# 1        12421                   6      Y      Yes                 12
# 2        23577                   4      Y      Yes                 13
# 3        20364                   1      Y       No                 13
# 4        15178                   1      Y       No                 14
#
#    PerformanceRating  RelationshipSatisfaction  StandardHours  \
# 0                  3                         4             80
# 1                  3                         3             80
# 2                  3                         2             80
# 3                  3                         3             80
# 4                  3                         1             80
#
#    StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  \
# 0                 0                  1                      2
# 1                 1                  7                      3
# 2                 2                 13                      2
# 3                 0                 14                      2
# 4                 0                  1                      5
#
#    WorkLifeBalance  YearsAtCompany  YearsInCurrentRole  \
# 0                2               1                   0
# 1                3               2                   2
# 2                2               7                   7
# 3                2              14                  10
# 4                3               1                   0
#
#    YearsSinceLastPromotion  YearsWithCurrManager  Count_BusinessTravel  \
# 0                        0                     0                   108
# 1                        2                     2                   799
# 2                        1                     7                   799
# 3                       11                     8                   799
# 4                        0                     0                   212
#
#    Count_Department  Count_EducationField  Count_Gender  Count_JobRole  \
# 0               777                   345           690            230
# 1               306                   102           690            240
# 2               777                   519           690            230
# 3               777                   519           690            112
# 4               777                   519           690            230
#
#    Count_MaritalStatus
# 0                  394
# 1                  201
# 2                  201
# 3                  394
# 4                  394

# %% [markdown]
# Now we have transform categorical variables to numerical using label encoder so the next thing we are going to do is to select our X and Y variable and then build a model.

# %%
X = train.drop(["Attrition"], axis=1)
y = train.Attrition
test = test.copy()

# %%
# Standarizing the data

# from sklearn.pipeline import Pipeline
# from sklearn.preprocessing import StandardScaler

# pipeline = Pipeline([("scale", StandardScaler())])

# X = pd.DataFrame(columns=X.columns, data=pipeline.fit_transform(X))
# test = pd.DataFrame(columns=test.columns, data=pipeline.fit_transform(test))

# %%
X.shape, test.shape
# Out:
# ((1677, 39), (1119, 39))

# %% [markdown]
# # Modeling

# %%
params = {
    "iterations": 10000,
    "objective": "Logloss",
    "colsample_bylevel": 0.08383650771477613,
    "depth": 11,
    "boosting_type": "Ordered",
    "bootstrap_type": "Bayesian",
    "bagging_temperature": 0.01880446878521802,
}

# %%
best_params = {
    "objective": "Logloss",
    "learning_rate": 0.1,
    "colsample_bylevel": 0.06451646696177094,
    "depth": 10,
    "boosting_type": "Plain",
    "bootstrap_type": "MVS",
    "n_estimators": 6549,
}

# %%
# %%time
kf = RepeatedKFold(n_splits=10, n_repeats=5, random_state=42)

preds = []
scores = []
feature_importance_df = pd.DataFrame()

for fold, (idx_train, idx_valid) in enumerate(kf.split(X, y)):
    X_train, y_train = X.iloc[idx_train], y.iloc[idx_train]
    X_valid, y_valid = X.iloc[idx_valid], y.iloc[idx_valid]

    model = CatBoostClassifier(**best_params, cat_features=cat_features)

    model.fit(
        X_train,
        y_train,
        eval_set=[(X_valid, y_valid)],
        verbose=False,
        early_stopping_rounds=100,
    )

    pred_valid = model.predict_proba(X_valid)[:, 1]
    fpr, tpr, _ = metrics.roc_curve(y_valid, pred_valid)
    score = metrics.auc(fpr, tpr)
    scores.append(score)

    fold_importance_df = pd.DataFrame()
    fold_importance_df["Feature"] = X.columns
    fold_importance_df["importance"] = model.feature_importances_
    fold_importance_df["fold"] = fold + 1
    feature_importance_df = pd.concat(
        [feature_importance_df, fold_importance_df], axis=0
    )

    print(f"Fold: {fold + 1} Score: {score}" "\n")
    print("||" * 40, "\n")

    test_preds = model.predict_proba(test)[:, 1]
    preds.append(test_preds)

print(f"Overall Validation Score: {np.mean(scores)}")
# Out:
# Fold: 1 Score: 0.7905405405405406
#
# ||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
#
# Fold: 2 Score: 0.8321759259259259
#
# ||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
#
# Fold: 3 Score: 0.8049886621315192
#
# ||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
#
# Fold: 4 Score: 0.8527463965718738
#
# ||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
#
# Fold: 5 Score: 0.7772113943028486
#
# ||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
#
# Fold: 6 Score: 0.8243085313595637
#
# ||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
#
# Fold: 7 Score: 0.8449564134495642
#
# ||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
#
# Fold: 8 Score: 0.8568027210884354
#
# ||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
#
# Fold: 9 Score: 0.9093281148075669
#
# ||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
#
# Fold: 10 Score: 0.8302631578947369
#
# ||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
#
# Fold: 11 Score: 0.7798879202988793
#
# ||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
#
# Fold: 12 Score: 0.8432282003710575
#
# ||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
#
# Fold: 13 Score: 0.8929535232383808
#
# ||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
#
# Fold: 14 Score: 0.8196099674972915
#
# ||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
#
# Fold: 15 Score: 0.8448979591836735
#
# ||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
#
# Fold: 16 Score: 0.8085519922254616
#
# ||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
#
# Fold: 17 Score: 0.8588607594936709
#
# ||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
#
# Fold: 18 Score: 0.8351449275362319
#
# ||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
#
# Fold: 19 Score: 0.7762863534675615
#
# ||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
#
# Fold: 20 Score: 0.8228070175438598
#
# ||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
#
# Fold: 21 Score: 0.7753444012716354
#
# ||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
#
# Fold: 22 Score: 0.8513119533527697
#
# ||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
#
# Fold: 23 Score: 0.7805105853051059
#
# ||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
#
# Fold: 24 Score: 0.8461289277615808
#
# ||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
#
# Fold: 25 Score: 0.8495231367008125
#
# ||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
#
# Fold: 26 Score: 0.8455944055944056
#
# ||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
#
# Fold: 27 Score: 0.8905380333951762
#
# ||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
#
# Fold: 28 Score: 0.855701754385965
#
# ||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
#
# Fold: 29 Score: 0.9153508771929826
#
# ||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
#
# Fold: 30 Score: 0.7991004497751124
#
# ||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
#
# Fold: 31 Score: 0.8470588235294118
#
# ||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
#
# Fold: 32 Score: 0.8361486486486486
#
# ||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
#
# Fold: 33 Score: 0.8083881578947368
#
# ||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
#
# Fold: 34 Score: 0.8576474743906747
#
# ||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
#
# Fold: 35 Score: 0.8050958760178618
#
# ||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
#
# Fold: 36 Score: 0.8585897935333073
#
# ||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
#
# Fold: 37 Score: 0.8679950186799502
#
# ||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
#
# Fold: 38 Score: 0.7397959183673469
#
# ||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
#
# Fold: 39 Score: 0.8061594202898551
#
# ||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
#
# Fold: 40 Score: 0.8568166992824527
#
# ||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
#
# Fold: 41 Score: 0.8461538461538461
#
# ||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
#
# Fold: 42 Score: 0.783676507070206
#
# ||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
#
# Fold: 43 Score: 0.8668831168831168
#
# ||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
#
# Fold: 44 Score: 0.830255911888565
#
# ||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
#
# Fold: 45 Score: 0.8172297297297297
#
# ||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
#
# Fold: 46 Score: 0.8493150684931507
#
# ||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
#
# Fold: 47 Score: 0.7230229840280483
#
# ||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
#
# Fold: 48 Score: 0.8372472276581865
#
# ||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
#
# Fold: 49 Score: 0.7521337126600284
#
# ||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
#
# Fold: 50 Score: 0.8543123543123543
#
# ||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
#
# Overall Validation Score: 0.8291716258635133
# CPU times: user 1min 40s, sys: 29.1 s, total: 2min 9s
# Wall time: 24.2 s

# %%
cols = (
    feature_importance_df[["Feature", "importance"]]
    .groupby("Feature")
    .mean()
    .sort_values(by="importance", ascending=False)[:107]
    .index
)
best_features = feature_importance_df.loc[feature_importance_df.Feature.isin(cols)]

plt.figure(figsize=(14, 28))
sns.barplot(
    x="importance",
    y="Feature",
    data=best_features.sort_values(by="importance", ascending=False),
)
plt.title("Features importance (averaged/folds)")
plt.tight_layout()
plt.savefig("FI.png")

# %%
ss.head()
# Out:
#      id  Attrition
# 0  1677   0.119261
# 1  1678   0.119261
# 2  1679   0.119261
# 3  1680   0.119261
# 4  1681   0.119261

# %%
predictions = np.mean(np.column_stack(preds), axis=1)

ss["Attrition"] = predictions
ss.to_csv("./cb_back.csv", index=False)
ss.head()
# Out:
#      id  Attrition
# 0  1677   0.215983
# 1  1678   0.050116
# 2  1679   0.042057
# 3  1680   0.053646
# 4  1681   0.463672

# %% [markdown]
# ## Hyperparameter turning with optuna.

# %%
import catboost as cb
import optuna
from optuna.integration import CatBoostPruningCallback
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split


def objective(trial: optuna.Trial) -> float:
    train_x, valid_x, train_y, valid_y = train_test_split(X, y, test_size=0.25)

    param = {
        "objective": trial.suggest_categorical(
            "objective", ["Logloss", "CrossEntropy"]
        ),
        "learning_rate": trial.suggest_categorical(
            "learning_rate", [0.006, 0.008, 0.01, 0.014, 0.017, 0.02, 0.1]
        ),
        "colsample_bylevel": trial.suggest_float(
            "colsample_bylevel", 0.01, 0.1, log=True
        ),
        "depth": trial.suggest_int("depth", 1, 12),
        "boosting_type": trial.suggest_categorical(
            "boosting_type", ["Ordered", "Plain"]
        ),
        "bootstrap_type": trial.suggest_categorical(
            "bootstrap_type", ["Bayesian", "Bernoulli", "MVS"]
        ),
        "used_ram_limit": "3gb",
        "eval_metric": "Accuracy",
        "n_estimators": trial.suggest_int("n_estimators", 1, 10000),
    }

    if param["bootstrap_type"] == "Bayesian":
        param["bagging_temperature"] = trial.suggest_float("bagging_temperature", 0, 10)
    elif param["bootstrap_type"] == "Bernoulli":
        param["subsample"] = trial.suggest_float("subsample", 0.1, 1, log=True)

    gbm = cb.CatBoostClassifier(**param, cat_features=cat_features)

    pruning_callback = CatBoostPruningCallback(trial, "Accuracy")
    gbm.fit(
        train_x,
        train_y,
        eval_set=[(valid_x, valid_y)],
        verbose=0,
        early_stopping_rounds=100,
        callbacks=[pruning_callback],
    )

    # evoke pruning manually.
    pruning_callback.check_pruned()

    preds = gbm.predict(valid_x)
    pred_labels = np.rint(preds)
    accuracy = accuracy_score(valid_y, pred_labels)

    return accuracy


if __name__ == "__main__":
    study = optuna.create_study(
        pruner=optuna.pruners.MedianPruner(n_warmup_steps=5), direction="maximize"
    )
    study.optimize(objective, n_trials=100, timeout=600)

    print("Number of finished trials: {}".format(len(study.trials)))

    print("Best trial:")
    trial = study.best_trial

    print("  Value: {}".format(trial.value))

    print("  Params: ")
    for key, value in trial.params.items():
        print("    {}: {}".format(key, value))
# Out:
# [I 2023-01-18 00:50:27,286] A new study created in memory with name: no-name-ac6c59a6-5356-4685-92cc-008bc42d9b3d
# [I 2023-01-18 00:50:28,818] Trial 0 finished with value: 0.8928571428571429 and parameters: {'objective': 'CrossEntropy', 'learning_rate': 0.1, 'colsample_bylevel': 0.05348264997059686, 'depth': 11, 'boosting_type': 'Ordered', 'bootstrap_type': 'MVS', 'n_estimators': 1286}. Best is trial 0 with value: 0.8928571428571429.
# [I 2023-01-18 00:50:29,040] Trial 1 finished with value: 0.8761904761904762 and parameters: {'objective': 'Logloss', 'learning_rate': 0.01, 'colsample_bylevel': 0.03123778453418205, 'depth': 12, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bernoulli', 'n_estimators': 5833, 'subsample': 0.11766369376740408}. Best is trial 0 with value: 0.8928571428571429.
# [I 2023-01-18 00:50:29,222] Trial 2 finished with value: 0.8809523809523809 and parameters: {'objective': 'CrossEntropy', 'learning_rate': 0.01, 'colsample_bylevel': 0.013656576100858674, 'depth': 7, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bayesian', 'n_estimators': 9755, 'bagging_temperature': 0.10058858238266133}. Best is trial 0 with value: 0.8928571428571429.
# [I 2023-01-18 00:50:29,395] Trial 3 finished with value: 0.8761904761904762 and parameters: {'objective': 'Logloss', 'learning_rate': 0.017, 'colsample_bylevel': 0.030690385595781845, 'depth': 10, 'boosting_type': 'Plain', 'bootstrap_type': 'Bernoulli', 'n_estimators': 8273, 'subsample': 0.1483312993930606}. Best is trial 0 with value: 0.8928571428571429.
# [I 2023-01-18 00:50:29,565] Trial 4 finished with value: 0.9023809523809524 and parameters: {'objective': 'CrossEntropy', 'learning_rate': 0.008, 'colsample_bylevel': 0.09600972952319178, 'depth': 4, 'boosting_type': 'Plain', 'bootstrap_type': 'MVS', 'n_estimators': 5441}. Best is trial 4 with value: 0.9023809523809524.
# [I 2023-01-18 00:50:29,593] Trial 5 pruned. Trial was pruned at iteration 5.
# [I 2023-01-18 00:50:29,812] Trial 6 finished with value: 0.8833333333333333 and parameters: {'objective': 'CrossEntropy', 'learning_rate': 0.008, 'colsample_bylevel': 0.011395988114195909, 'depth': 1, 'boosting_type': 'Ordered', 'bootstrap_type': 'MVS', 'n_estimators': 7704}. Best is trial 4 with value: 0.9023809523809524.
# [I 2023-01-18 00:50:30,042] Trial 7 finished with value: 0.888095238095238 and parameters: {'objective': 'CrossEntropy', 'learning_rate': 0.017, 'colsample_bylevel': 0.023830039203142646, 'depth': 11, 'boosting_type': 'Plain', 'bootstrap_type': 'MVS', 'n_estimators': 5531}. Best is trial 4 with value: 0.9023809523809524.
# [I 2023-01-18 00:50:30,227] Trial 8 finished with value: 0.8928571428571429 and parameters: {'objective': 'Logloss', 'learning_rate': 0.1, 'colsample_bylevel': 0.01390074521005545, 'depth': 4, 'boosting_type': 'Plain', 'bootstrap_type': 'MVS', 'n_estimators': 3830}. Best is trial 4 with value: 0.9023809523809524.
# [I 2023-01-18 00:50:30,462] Trial 9 finished with value: 0.8904761904761904 and parameters: {'objective': 'CrossEntropy', 'learning_rate': 0.006, 'colsample_bylevel': 0.027194824931129888, 'depth': 7, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bernoulli', 'n_estimators': 3795, 'subsample': 0.7652023931806633}. Best is trial 4 with value: 0.9023809523809524.
# [I 2023-01-18 00:50:30,495] Trial 10 pruned. Trial was pruned at iteration 5.
# [I 2023-01-18 00:50:30,546] Trial 11 pruned. Trial was pruned at iteration 5.
# [I 2023-01-18 00:50:30,795] Trial 12 finished with value: 0.8857142857142857 and parameters: {'objective': 'CrossEntropy', 'learning_rate': 0.014, 'colsample_bylevel': 0.05739516317413168, 'depth': 4, 'boosting_type': 'Ordered', 'bootstrap_type': 'MVS', 'n_estimators': 2281}. Best is trial 4 with value: 0.9023809523809524.
# [I 2023-01-18 00:50:30,894] Trial 13 pruned. Trial was pruned at iteration 5.
# [I 2023-01-18 00:50:30,962] Trial 14 pruned. Trial was pruned at iteration 5.
# [I 2023-01-18 00:50:31,011] Trial 15 pruned. Trial was pruned at iteration 5.
# [I 2023-01-18 00:50:31,279] Trial 16 finished with value: 0.8833333333333333 and parameters: {'objective': 'CrossEntropy', 'learning_rate': 0.014, 'colsample_bylevel': 0.04277933031953172, 'depth': 8, 'boosting_type': 'Ordered', 'bootstrap_type': 'MVS', 'n_estimators': 4417}. Best is trial 4 with value: 0.9023809523809524.
# [I 2023-01-18 00:50:31,466] Trial 17 finished with value: 0.8833333333333333 and parameters: {'objective': 'CrossEntropy', 'learning_rate': 0.006, 'colsample_bylevel': 0.061552423473378706, 'depth': 3, 'boosting_type': 'Plain', 'bootstrap_type': 'MVS', 'n_estimators': 6429}. Best is trial 4 with value: 0.9023809523809524.
# [I 2023-01-18 00:50:34,337] Trial 18 finished with value: 0.9023809523809524 and parameters: {'objective': 'Logloss', 'learning_rate': 0.1, 'colsample_bylevel': 0.09872430062082986, 'depth': 12, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bernoulli', 'n_estimators': 4793, 'subsample': 0.9378438507948164}. Best is trial 4 with value: 0.9023809523809524.
# [I 2023-01-18 00:50:34,371] Trial 19 pruned. Trial was pruned at iteration 5.
# [I 2023-01-18 00:50:34,607] Trial 20 pruned. Trial was pruned at iteration 108.
# [I 2023-01-18 00:50:39,210] Trial 21 finished with value: 0.9214285714285714 and parameters: {'objective': 'Logloss', 'learning_rate': 0.1, 'colsample_bylevel': 0.06024497279158142, 'depth': 12, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bernoulli', 'n_estimators': 1570, 'subsample': 0.34478791868554093}. Best is trial 21 with value: 0.9214285714285714.
# [I 2023-01-18 00:50:39,310] Trial 22 pruned. Trial was pruned at iteration 5.
# [I 2023-01-18 00:50:40,250] Trial 23 finished with value: 0.9071428571428571 and parameters: {'objective': 'Logloss', 'learning_rate': 0.1, 'colsample_bylevel': 0.03982602131173165, 'depth': 11, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bernoulli', 'n_estimators': 5329, 'subsample': 0.560568112152584}. Best is trial 21 with value: 0.9214285714285714.
# [I 2023-01-18 00:50:41,212] Trial 24 finished with value: 0.9214285714285714 and parameters: {'objective': 'Logloss', 'learning_rate': 0.1, 'colsample_bylevel': 0.03877555652618555, 'depth': 11, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bernoulli', 'n_estimators': 2748, 'subsample': 0.5406553682744366}. Best is trial 21 with value: 0.9214285714285714.
# [I 2023-01-18 00:50:41,479] Trial 25 pruned. Trial was pruned at iteration 101.
# [I 2023-01-18 00:50:41,524] Trial 26 finished with value: 0.8952380952380953 and parameters: {'objective': 'Logloss', 'learning_rate': 0.1, 'colsample_bylevel': 0.037270743075922035, 'depth': 11, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bernoulli', 'n_estimators': 10, 'subsample': 0.20591498575426387}. Best is trial 21 with value: 0.9214285714285714.
# [I 2023-01-18 00:50:41,557] Trial 27 pruned. Trial was pruned at iteration 5.
# [I 2023-01-18 00:50:41,608] Trial 28 pruned. Trial was pruned at iteration 5.
# [I 2023-01-18 00:50:41,648] Trial 29 pruned. Trial was pruned at iteration 5.
# [I 2023-01-18 00:50:41,689] Trial 30 pruned. Trial was pruned at iteration 5.
# [I 2023-01-18 00:50:41,776] Trial 31 pruned. Trial was pruned at iteration 5.
# [I 2023-01-18 00:50:41,815] Trial 32 pruned. Trial was pruned at iteration 5.
# [I 2023-01-18 00:50:41,859] Trial 33 pruned. Trial was pruned at iteration 5.
# [I 2023-01-18 00:50:41,901] Trial 34 pruned. Trial was pruned at iteration 5.
# [I 2023-01-18 00:50:41,943] Trial 35 pruned. Trial was pruned at iteration 5.
# [I 2023-01-18 00:50:41,986] Trial 36 pruned. Trial was pruned at iteration 5.
# [I 2023-01-18 00:50:42,085] Trial 37 pruned. Trial was pruned at iteration 5.
# [I 2023-01-18 00:50:42,325] Trial 38 finished with value: 0.888095238095238 and parameters: {'objective': 'Logloss', 'learning_rate': 0.014, 'colsample_bylevel': 0.02608809229497795, 'depth': 12, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bernoulli', 'n_estimators': 4397, 'subsample': 0.6117669257435207}. Best is trial 21 with value: 0.9214285714285714.
# [I 2023-01-18 00:50:42,897] Trial 39 pruned. Trial was pruned at iteration 101.
# [I 2023-01-18 00:50:42,932] Trial 40 pruned. Trial was pruned at iteration 5.
# [I 2023-01-18 00:50:43,488] Trial 41 finished with value: 0.9095238095238095 and parameters: {'objective': 'Logloss', 'learning_rate': 0.017, 'colsample_bylevel': 0.08890912908376548, 'depth': 10, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bernoulli', 'n_estimators': 5107, 'subsample': 0.3477893509291379}. Best is trial 21 with value: 0.9214285714285714.
# [I 2023-01-18 00:50:43,535] Trial 42 pruned. Trial was pruned at iteration 5.
# [I 2023-01-18 00:50:43,625] Trial 43 pruned. Trial was pruned at iteration 5.
# [I 2023-01-18 00:50:43,660] Trial 44 pruned. Trial was pruned at iteration 5.
# [I 2023-01-18 00:50:43,717] Trial 45 pruned. Trial was pruned at iteration 5.
# [I 2023-01-18 00:50:43,754] Trial 46 pruned. Trial was pruned at iteration 5.
# [I 2023-01-18 00:50:43,990] Trial 47 finished with value: 0.9 and parameters: {'objective': 'CrossEntropy', 'learning_rate': 0.01, 'colsample_bylevel': 0.07150606265146846, 'depth': 7, 'boosting_type': 'Plain', 'bootstrap_type': 'MVS', 'n_estimators': 1212}. Best is trial 21 with value: 0.9214285714285714.
# [I 2023-01-18 00:50:44,024] Trial 48 pruned. Trial was pruned at iteration 5.
# [I 2023-01-18 00:50:44,070] Trial 49 pruned. Trial was pruned at iteration 5.
# [I 2023-01-18 00:50:44,266] Trial 50 finished with value: 0.8904761904761904 and parameters: {'objective': 'CrossEntropy', 'learning_rate': 0.014, 'colsample_bylevel': 0.04701442822592215, 'depth': 2, 'boosting_type': 'Ordered', 'bootstrap_type': 'MVS', 'n_estimators': 5745}. Best is trial 21 with value: 0.9214285714285714.
# [I 2023-01-18 00:50:44,334] Trial 51 pruned. Trial was pruned at iteration 5.
# [I 2023-01-18 00:50:44,405] Trial 52 pruned. Trial was pruned at iteration 5.
# [I 2023-01-18 00:50:47,061] Trial 53 pruned. Trial was pruned at iteration 161.
# [I 2023-01-18 00:50:47,142] Trial 54 pruned. Trial was pruned at iteration 5.
# [I 2023-01-18 00:50:47,226] Trial 55 pruned. Trial was pruned at iteration 5.
# [I 2023-01-18 00:50:47,382] Trial 56 pruned. Trial was pruned at iteration 5.
# [I 2023-01-18 00:50:47,416] Trial 57 pruned. Trial was pruned at iteration 5.
# [I 2023-01-18 00:50:47,512] Trial 58 pruned. Trial was pruned at iteration 5.
# [I 2023-01-18 00:50:47,556] Trial 59 pruned. Trial was pruned at iteration 5.
# [I 2023-01-18 00:50:47,593] Trial 60 pruned. Trial was pruned at iteration 5.
# [I 2023-01-18 00:50:47,855] Trial 61 finished with value: 0.8952380952380953 and parameters: {'objective': 'CrossEntropy', 'learning_rate': 0.01, 'colsample_bylevel': 0.06980607333044024, 'depth': 6, 'boosting_type': 'Plain', 'bootstrap_type': 'MVS', 'n_estimators': 1161}. Best is trial 21 with value: 0.9214285714285714.
# [I 2023-01-18 00:50:47,901] Trial 62 pruned. Trial was pruned at iteration 5.
# [I 2023-01-18 00:50:48,138] Trial 63 finished with value: 0.919047619047619 and parameters: {'objective': 'CrossEntropy', 'learning_rate': 0.01, 'colsample_bylevel': 0.07255694118480809, 'depth': 6, 'boosting_type': 'Plain', 'bootstrap_type': 'MVS', 'n_estimators': 1387}. Best is trial 21 with value: 0.9214285714285714.
# [I 2023-01-18 00:50:48,171] Trial 64 pruned. Trial was pruned at iteration 5.
# [I 2023-01-18 00:50:48,553] Trial 65 pruned. Trial was pruned at iteration 161.
# [I 2023-01-18 00:50:49,146] Trial 66 finished with value: 0.9261904761904762 and parameters: {'objective': 'Logloss', 'learning_rate': 0.1, 'colsample_bylevel': 0.08251598034253296, 'depth': 5, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bernoulli', 'n_estimators': 1516, 'subsample': 0.9631143019123137}. Best is trial 66 with value: 0.9261904761904762.
# [I 2023-01-18 00:50:49,186] Trial 67 pruned. Trial was pruned at iteration 5.
# [I 2023-01-18 00:50:49,488] Trial 68 finished with value: 0.8928571428571429 and parameters: {'objective': 'CrossEntropy', 'learning_rate': 0.014, 'colsample_bylevel': 0.08560191983985456, 'depth': 6, 'boosting_type': 'Plain', 'bootstrap_type': 'Bayesian', 'n_estimators': 973, 'bagging_temperature': 7.109342700375607}. Best is trial 66 with value: 0.9261904761904762.
# [I 2023-01-18 00:50:49,533] Trial 69 pruned. Trial was pruned at iteration 5.
# [I 2023-01-18 00:50:49,586] Trial 70 pruned. Trial was pruned at iteration 5.
# [I 2023-01-18 00:50:49,635] Trial 71 pruned. Trial was pruned at iteration 5.
# [I 2023-01-18 00:50:49,687] Trial 72 pruned. Trial was pruned at iteration 5.
# [I 2023-01-18 00:50:49,728] Trial 73 pruned. Trial was pruned at iteration 5.
# [I 2023-01-18 00:50:49,767] Trial 74 pruned. Trial was pruned at iteration 5.
# [I 2023-01-18 00:50:50,530] Trial 75 pruned. Trial was pruned at iteration 101.
# [I 2023-01-18 00:50:50,600] Trial 76 pruned. Trial was pruned at iteration 5.
# [I 2023-01-18 00:50:50,642] Trial 77 pruned. Trial was pruned at iteration 5.
# [I 2023-01-18 00:50:50,686] Trial 78 pruned. Trial was pruned at iteration 5.
# [I 2023-01-18 00:50:50,726] Trial 79 pruned. Trial was pruned at iteration 5.
# [I 2023-01-18 00:50:50,823] Trial 80 pruned. Trial was pruned at iteration 5.
# [I 2023-01-18 00:50:50,872] Trial 81 pruned. Trial was pruned at iteration 5.
# [I 2023-01-18 00:50:50,914] Trial 82 pruned. Trial was pruned at iteration 5.
# [I 2023-01-18 00:50:50,962] Trial 83 pruned. Trial was pruned at iteration 5.
# [I 2023-01-18 00:50:51,278] Trial 84 pruned. Trial was pruned at iteration 101.
# [I 2023-01-18 00:50:51,317] Trial 85 pruned. Trial was pruned at iteration 5.
# [I 2023-01-18 00:50:51,568] Trial 86 pruned. Trial was pruned at iteration 101.
# [I 2023-01-18 00:50:51,612] Trial 87 pruned. Trial was pruned at iteration 5.
# [I 2023-01-18 00:50:51,655] Trial 88 pruned. Trial was pruned at iteration 5.
# [I 2023-01-18 00:50:51,749] Trial 89 pruned. Trial was pruned at iteration 5.
# [I 2023-01-18 00:50:51,796] Trial 90 pruned. Trial was pruned at iteration 5.
# [I 2023-01-18 00:50:52,054] Trial 91 finished with value: 0.9047619047619048 and parameters: {'objective': 'CrossEntropy', 'learning_rate': 0.01, 'colsample_bylevel': 0.06928816510170384, 'depth': 6, 'boosting_type': 'Plain', 'bootstrap_type': 'MVS', 'n_estimators': 1755}. Best is trial 66 with value: 0.9261904761904762.
# [I 2023-01-18 00:50:52,128] Trial 92 pruned. Trial was pruned at iteration 5.
# [I 2023-01-18 00:50:52,346] Trial 93 finished with value: 0.8952380952380953 and parameters: {'objective': 'CrossEntropy', 'learning_rate': 0.01, 'colsample_bylevel': 0.06330551135062686, 'depth': 6, 'boosting_type': 'Plain', 'bootstrap_type': 'MVS', 'n_estimators': 1879}. Best is trial 66 with value: 0.9261904761904762.
# [I 2023-01-18 00:50:52,409] Trial 94 pruned. Trial was pruned at iteration 5.
# [I 2023-01-18 00:50:52,457] Trial 95 pruned. Trial was pruned at iteration 5.
# [I 2023-01-18 00:50:52,504] Trial 96 pruned. Trial was pruned at iteration 5.
# [I 2023-01-18 00:50:52,555] Trial 97 pruned. Trial was pruned at iteration 5.
# [I 2023-01-18 00:50:52,610] Trial 98 pruned. Trial was pruned at iteration 5.
# [I 2023-01-18 00:50:52,685] Trial 99 pruned. Trial was pruned at iteration 5.
# Number of finished trials: 100
# Best trial:
#   Value: 0.9261904761904762
#   Params:
#     objective: Logloss
#     learning_rate: 0.1
#     colsample_bylevel: 0.08251598034253296
#     depth: 5
#     boosting_type: Ordered
#     bootstrap_type: Bernoulli
#     n_estimators: 1516
#     subsample: 0.9631143019123137
