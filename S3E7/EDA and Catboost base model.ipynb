# %% [markdown]
# # Importing libraries

# %%
import warnings

import matplotlib.pyplot as plt
import missingno as mn
import numpy as np
import pandas as pd
import plotly.express as px
from plotly.offline import download_plotlyjs, init_notebook_mode, iplot, plot
from tqdm import tqdm

init_notebook_mode(connected=True)
import seaborn as sns
from catboost import CatBoostClassifier
from lightgbm import LGBMClassifier
from sklearn import metrics
from sklearn.model_selection import (
    KFold,
    RepeatedKFold,
    RepeatedStratifiedKFold,
    StratifiedKFold,
)
from sklearn.preprocessing import LabelEncoder, OneHotEncoder

pd.set_option("display.max_columns", 50)
warnings.filterwarnings("ignore")
# warnings.filterwarnings("ignore", category="FutureWarning")
# warnings.filterwarnings("ignore", category="DeprecationWarning")
# warnings.filterwarnings("ignore", category="UserWarning")

# Color Palette
custom_colors = ["#7400ff", "#a788e4", "#d216d2", "#ffb500", "#36c9dd"]
sns.palplot(sns.color_palette(custom_colors))

# Set Style
sns.set_style("whitegrid")
sns.despine(left=True, bottom=True)

# Set tick size
plt.rc("xtick", labelsize=12)
plt.rc("ytick", labelsize=12)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.12.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# ## Loading the data

# %%
train = pd.read_csv("train.csv").drop("id", axis=1)
test = pd.read_csv("test.csv").drop("id", axis=1)
ss = pd.read_csv("sample_submission.csv")

# %%
train.head()
# Out:
#    Age     BusinessTravel  DailyRate              Department  \
# 0   36  Travel_Frequently        599  Research & Development
# 1   35      Travel_Rarely        921                   Sales
# 2   32      Travel_Rarely        718                   Sales
# 3   38      Travel_Rarely       1488  Research & Development
# 4   50      Travel_Rarely       1017  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  \
# 0                24          3        Medical              1
# 1                 8          3          Other              1
# 2                26          3      Marketing              1
# 3                 2          3        Medical              1
# 4                 5          4        Medical              1
#
#    EnvironmentSatisfaction  Gender  HourlyRate  JobInvolvement  JobLevel  \
# 0                        4    Male          42               3         1
# 1                        1    Male          46               3         1
# 2                        3    Male          80               3         2
# 3                        3  Female          40               3         2
# 4                        2  Female          37               3         5
#
#                      JobRole  JobSatisfaction MaritalStatus  MonthlyIncome  \
# 0      Laboratory Technician                4       Married           2596
# 1       Sales Representative                1       Married           2899
# 2            Sales Executive                4      Divorced           4627
# 3  Healthcare Representative                1       Married           5347
# 4                    Manager                1        Single          19033
#
#    MonthlyRate  NumCompaniesWorked Over18 OverTime  PercentSalaryHike  \
# 0         5099                   1      Y      Yes                 13
# 1        10778                   1      Y       No                 17
# 2        16495                   0      Y       No                 17
# 3        13384                   3      Y       No                 14
# 4        19805                   1      Y      Yes                 13
#
#    PerformanceRating  RelationshipSatisfaction  StandardHours  \
# 0                  3                         2             80
# 1                  3                         4             80
# 2                  3                         4             80
# 3                  3                         3             80
# 4                  3                         3             80
#
#    StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  \
# 0                 1                 10                      2
# 1                 1                  4                      3
# 2                 2                  4                      3
# 3                 0                 15                      1
# 4                 0                 31                      0
#
#    WorkLifeBalance  YearsAtCompany  YearsInCurrentRole  \
# 0                3              10                   0
# 1                3               4                   2
# 2                3               3                   2
# 3                1               6                   0
# 4                3              31                  14
#
#    YearsSinceLastPromotion  YearsWithCurrManager  Attrition
# 0                        7                     8          0
# 1                        0                     3          0
# 2                        1                     2          0
# 3                        0                     2          0
# 4                        4                    10          1

# %%
test.head()
# Out:
#    Age     BusinessTravel  DailyRate              Department  \
# 0   19         Non-Travel        992  Research & Development
# 1   45      Travel_Rarely       1136                   Sales
# 2   37      Travel_Rarely        155  Research & Development
# 3   32      Travel_Rarely        688  Research & Development
# 4   29  Travel_Frequently        464  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  \
# 0                 1          1        Medical              1
# 1                 4          4      Marketing              1
# 2                13          3  Life Sciences              1
# 3                 1          4  Life Sciences              1
# 4                 9          1  Life Sciences              1
#
#    EnvironmentSatisfaction Gender  HourlyRate  JobInvolvement  JobLevel  \
# 0                        4   Male          43               3         1
# 1                        3   Male          67               3         2
# 2                        4   Male          41               3         1
# 3                        3   Male          89               2         2
# 4                        3   Male          79               3         1
#
#                      JobRole  JobSatisfaction MaritalStatus  MonthlyIncome  \
# 0      Laboratory Technician                3        Single           2318
# 1            Sales Executive                1      Divorced           5486
# 2         Research Scientist                4      Divorced           2741
# 3  Healthcare Representative                3        Single           5228
# 4      Laboratory Technician                4        Single           1223
#
#    MonthlyRate  NumCompaniesWorked Over18 OverTime  PercentSalaryHike  \
# 0        17778                   1      Y       No                 12
# 1        12421                   6      Y      Yes                 12
# 2        23577                   4      Y      Yes                 13
# 3        20364                   1      Y       No                 13
# 4        15178                   1      Y       No                 14
#
#    PerformanceRating  RelationshipSatisfaction  StandardHours  \
# 0                  3                         4             80
# 1                  3                         3             80
# 2                  3                         2             80
# 3                  3                         3             80
# 4                  3                         1             80
#
#    StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  \
# 0                 0                  1                      2
# 1                 1                  7                      3
# 2                 2                 13                      2
# 3                 0                 14                      2
# 4                 0                  1                      5
#
#    WorkLifeBalance  YearsAtCompany  YearsInCurrentRole  \
# 0                2               1                   0
# 1                3               2                   2
# 2                2               7                   7
# 3                2              14                  10
# 4                3               1                   0
#
#    YearsSinceLastPromotion  YearsWithCurrManager
# 0                        0                     0
# 1                        2                     2
# 2                        1                     7
# 3                       11                     8
# 4                        0                     0

# %%
ss.head()
# Out:
#      id  Attrition
# 0  1677   0.119261
# 1  1678   0.119261
# 2  1679   0.119261
# 3  1680   0.119261
# 4  1681   0.119261

# %%
# Looking at the size of the data
train.shape, test.shape
# Out:
# ((1677, 34), (1119, 33))

# %%
train.describe().T.style.bar(
    subset=["mean"], color=custom_colors[1]
).background_gradient(subset=["std"], cmap="Reds").background_gradient(
    subset=["50%"], cmap="coolwarm"
)
# Out:
# <style type="text/css">
# #T_4717a_row0_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #a788e4 0.2%, transparent 0.2%);
# }
# #T_4717a_row0_col2, #T_4717a_row2_col2, #T_4717a_row3_col2, #T_4717a_row4_col2, #T_4717a_row5_col2, #T_4717a_row6_col2, #T_4717a_row7_col2, #T_4717a_row8_col2, #T_4717a_row9_col2, #T_4717a_row12_col2, #T_4717a_row13_col2, #T_4717a_row14_col2, #T_4717a_row15_col2, #T_4717a_row16_col2, #T_4717a_row17_col2, #T_4717a_row18_col2, #T_4717a_row19_col2, #T_4717a_row20_col2, #T_4717a_row21_col2, #T_4717a_row22_col2, #T_4717a_row23_col2, #T_4717a_row24_col2, #T_4717a_row25_col2 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# #T_4717a_row0_col5, #T_4717a_row2_col5, #T_4717a_row3_col5, #T_4717a_row4_col5, #T_4717a_row5_col5, #T_4717a_row7_col5, #T_4717a_row8_col5, #T_4717a_row9_col5, #T_4717a_row12_col5, #T_4717a_row13_col5, #T_4717a_row14_col5, #T_4717a_row15_col5, #T_4717a_row17_col5, #T_4717a_row18_col5, #T_4717a_row19_col5, #T_4717a_row20_col5, #T_4717a_row21_col5, #T_4717a_row22_col5, #T_4717a_row23_col5, #T_4717a_row24_col5, #T_4717a_row25_col5 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_4717a_row1_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #a788e4 6.0%, transparent 6.0%);
# }
# #T_4717a_row1_col2 {
#   background-color: #ffece4;
#   color: #000000;
# }
# #T_4717a_row1_col5 {
#   background-color: #4b64d5;
#   color: #f1f1f1;
# }
# #T_4717a_row2_col1, #T_4717a_row13_col1, #T_4717a_row18_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #a788e4 0.1%, transparent 0.1%);
# }
# #T_4717a_row3_col1, #T_4717a_row4_col1, #T_4717a_row5_col1, #T_4717a_row7_col1, #T_4717a_row8_col1, #T_4717a_row9_col1, #T_4717a_row12_col1, #T_4717a_row14_col1, #T_4717a_row15_col1, #T_4717a_row17_col1, #T_4717a_row19_col1, #T_4717a_row20_col1, #T_4717a_row21_col1, #T_4717a_row22_col1, #T_4717a_row23_col1, #T_4717a_row24_col1, #T_4717a_row25_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #a788e4 0.0%, transparent 0.0%);
# }
# #T_4717a_row6_col1, #T_4717a_row16_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #a788e4 0.5%, transparent 0.5%);
# }
# #T_4717a_row6_col5, #T_4717a_row16_col5 {
#   background-color: #3c4ec2;
#   color: #f1f1f1;
# }
# #T_4717a_row10_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #a788e4 42.0%, transparent 42.0%);
# }
# #T_4717a_row10_col2 {
#   background-color: #ec382b;
#   color: #f1f1f1;
# }
# #T_4717a_row10_col5 {
#   background-color: #a3c2fe;
#   color: #000000;
# }
# #T_4717a_row11_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #a788e4 100.0%, transparent 100.0%);
# }
# #T_4717a_row11_col2 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_4717a_row11_col5 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_4717a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4717a_level0_col0" class="col_heading level0 col0" >count</th>
#       <th id="T_4717a_level0_col1" class="col_heading level0 col1" >mean</th>
#       <th id="T_4717a_level0_col2" class="col_heading level0 col2" >std</th>
#       <th id="T_4717a_level0_col3" class="col_heading level0 col3" >min</th>
#       <th id="T_4717a_level0_col4" class="col_heading level0 col4" >25%</th>
#       <th id="T_4717a_level0_col5" class="col_heading level0 col5" >50%</th>
#       <th id="T_4717a_level0_col6" class="col_heading level0 col6" >75%</th>
#       <th id="T_4717a_level0_col7" class="col_heading level0 col7" >max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4717a_level0_row0" class="row_heading level0 row0" >Age</th>
#       <td id="T_4717a_row0_col0" class="data row0 col0" >1677.000000</td>
#       <td id="T_4717a_row0_col1" class="data row0 col1" >36.036971</td>
#       <td id="T_4717a_row0_col2" class="data row0 col2" >8.507112</td>
#       <td id="T_4717a_row0_col3" class="data row0 col3" >18.000000</td>
#       <td id="T_4717a_row0_col4" class="data row0 col4" >30.000000</td>
#       <td id="T_4717a_row0_col5" class="data row0 col5" >35.000000</td>
#       <td id="T_4717a_row0_col6" class="data row0 col6" >41.000000</td>
#       <td id="T_4717a_row0_col7" class="data row0 col7" >60.000000</td>
#     </tr>
#     <tr>
#       <th id="T_4717a_level0_row1" class="row_heading level0 row1" >DailyRate</th>
#       <td id="T_4717a_row1_col0" class="data row1 col0" >1677.000000</td>
#       <td id="T_4717a_row1_col1" class="data row1 col1" >892.749553</td>
#       <td id="T_4717a_row1_col2" class="data row1 col2" >374.496259</td>
#       <td id="T_4717a_row1_col3" class="data row1 col3" >107.000000</td>
#       <td id="T_4717a_row1_col4" class="data row1 col4" >589.000000</td>
#       <td id="T_4717a_row1_col5" class="data row1 col5" >890.000000</td>
#       <td id="T_4717a_row1_col6" class="data row1 col6" >1223.000000</td>
#       <td id="T_4717a_row1_col7" class="data row1 col7" >3921.000000</td>
#     </tr>
#     <tr>
#       <th id="T_4717a_level0_row2" class="row_heading level0 row2" >DistanceFromHome</th>
#       <td id="T_4717a_row2_col0" class="data row2 col0" >1677.000000</td>
#       <td id="T_4717a_row2_col1" class="data row2 col1" >8.683959</td>
#       <td id="T_4717a_row2_col2" class="data row2 col2" >7.826143</td>
#       <td id="T_4717a_row2_col3" class="data row2 col3" >1.000000</td>
#       <td id="T_4717a_row2_col4" class="data row2 col4" >2.000000</td>
#       <td id="T_4717a_row2_col5" class="data row2 col5" >7.000000</td>
#       <td id="T_4717a_row2_col6" class="data row2 col6" >12.000000</td>
#       <td id="T_4717a_row2_col7" class="data row2 col7" >29.000000</td>
#     </tr>
#     <tr>
#       <th id="T_4717a_level0_row3" class="row_heading level0 row3" >Education</th>
#       <td id="T_4717a_row3_col0" class="data row3 col0" >1677.000000</td>
#       <td id="T_4717a_row3_col1" class="data row3 col1" >2.937984</td>
#       <td id="T_4717a_row3_col2" class="data row3 col2" >1.039078</td>
#       <td id="T_4717a_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_4717a_row3_col4" class="data row3 col4" >2.000000</td>
#       <td id="T_4717a_row3_col5" class="data row3 col5" >3.000000</td>
#       <td id="T_4717a_row3_col6" class="data row3 col6" >4.000000</td>
#       <td id="T_4717a_row3_col7" class="data row3 col7" >15.000000</td>
#     </tr>
#     <tr>
#       <th id="T_4717a_level0_row4" class="row_heading level0 row4" >EmployeeCount</th>
#       <td id="T_4717a_row4_col0" class="data row4 col0" >1677.000000</td>
#       <td id="T_4717a_row4_col1" class="data row4 col1" >1.000000</td>
#       <td id="T_4717a_row4_col2" class="data row4 col2" >0.000000</td>
#       <td id="T_4717a_row4_col3" class="data row4 col3" >1.000000</td>
#       <td id="T_4717a_row4_col4" class="data row4 col4" >1.000000</td>
#       <td id="T_4717a_row4_col5" class="data row4 col5" >1.000000</td>
#       <td id="T_4717a_row4_col6" class="data row4 col6" >1.000000</td>
#       <td id="T_4717a_row4_col7" class="data row4 col7" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_4717a_level0_row5" class="row_heading level0 row5" >EnvironmentSatisfaction</th>
#       <td id="T_4717a_row5_col0" class="data row5 col0" >1677.000000</td>
#       <td id="T_4717a_row5_col1" class="data row5 col1" >2.757901</td>
#       <td id="T_4717a_row5_col2" class="data row5 col2" >1.086835</td>
#       <td id="T_4717a_row5_col3" class="data row5 col3" >1.000000</td>
#       <td id="T_4717a_row5_col4" class="data row5 col4" >2.000000</td>
#       <td id="T_4717a_row5_col5" class="data row5 col5" >3.000000</td>
#       <td id="T_4717a_row5_col6" class="data row5 col6" >4.000000</td>
#       <td id="T_4717a_row5_col7" class="data row5 col7" >4.000000</td>
#     </tr>
#     <tr>
#       <th id="T_4717a_level0_row6" class="row_heading level0 row6" >HourlyRate</th>
#       <td id="T_4717a_row6_col0" class="data row6 col0" >1677.000000</td>
#       <td id="T_4717a_row6_col1" class="data row6 col1" >67.798450</td>
#       <td id="T_4717a_row6_col2" class="data row6 col2" >19.435928</td>
#       <td id="T_4717a_row6_col3" class="data row6 col3" >30.000000</td>
#       <td id="T_4717a_row6_col4" class="data row6 col4" >51.000000</td>
#       <td id="T_

# %% [markdown]
# ### Distribution of the target variable

# %%
sns.countplot(train["Attrition"], color=custom_colors[1])
# Out:
# <AxesSubplot:ylabel='count'>

# %% [markdown]
# We can see that our data is unbalanced which mean it's a problem so we have to be care with this kind of problem.

# %%
train["Attrition"].value_counts().plot(kind="bar", color=custom_colors[1])
# Out:
# <AxesSubplot:>

# %%
# selecting categorical features
cat_features = [
    f for f in train.columns if f not in train.select_dtypes(include=["float", "int"])
]

# %%
cat_features
# Out:
# ['BusinessTravel',
#  'Department',
#  'EducationField',
#  'Gender',
#  'JobRole',
#  'MaritalStatus',
#  'Over18',
#  'OverTime']

# %%
## Distributions of all categorical features
# Use a for loop to create a countplot for each feature
for feature in cat_features:
    plt.figure()
    sns.countplot(x=feature, data=train, color=custom_colors[2], orient="h")
    plt.show()

# %% [markdown]
# ## Features Engineering on categorical features

# %%
# count of BusinessTravel
train["Count_BusinessTravel"] = train["BusinessTravel"].map(
    train["BusinessTravel"].value_counts().to_dict()
)
test["Count_BusinessTravel"] = test["BusinessTravel"].map(
    test["BusinessTravel"].value_counts().to_dict()
)
# Count of Department
train["Count_Department"] = train["Department"].map(
    train["Department"].value_counts().to_dict()
)
test["Count_Department"] = test["Department"].map(
    test["Department"].value_counts().to_dict()
)

# Count of EducationField
train["Count_EducationField"] = train["EducationField"].map(
    train["EducationField"].value_counts().to_dict()
)
test["Count_EducationField"] = test["EducationField"].map(
    test["EducationField"].value_counts().to_dict()
)

# Gender Count

train["Count_Gender"] = train["Gender"].map(train["Gender"].value_counts().to_dict())
test["Count_Gender"] = test["Gender"].map(test["Gender"].value_counts().to_dict())

# JobRole Count
train["Count_JobRole"] = train["JobRole"].map(train["JobRole"].value_counts().to_dict())
test["Count_JobRole"] = test["JobRole"].map(test["JobRole"].value_counts().to_dict())

# MaritalStatus Count
train["Count_MaritalStatus"] = train["MaritalStatus"].map(
    train["MaritalStatus"].value_counts().to_dict()
)
test["Count_MaritalStatus"] = test["MaritalStatus"].map(
    test["MaritalStatus"].value_counts().to_dict()
)

# %% [markdown]
#  Now it's time to LabelEncode categorical features

# %%
for col in cat_features:
    # initialize Label encoder for each features
    le = LabelEncoder()
    # fit transform label encoder on all data
    train[col] = le.fit_transform(train[col])
    test[col] = le.fit_transform(test[col])
train.head()
# Out:
#    Age  BusinessTravel  DailyRate  Department  DistanceFromHome  Education  \
# 0   36               1        599           1                24          3
# 1   35               2        921           2                 8          3
# 2   32               2        718           2                26          3
# 3   38               2       1488           1                 2          3
# 4   50               2       1017           1                 5          4
#
#    EducationField  EmployeeCount  EnvironmentSatisfaction  Gender  HourlyRate  \
# 0               3              1                        4       1          42
# 1               4              1                        1       1          46
# 2               2              1                        3       1          80
# 3               3              1                        3       0          40
# 4               3              1                        2       0          37
#
#    JobInvolvement  JobLevel  JobRole  JobSatisfaction  MaritalStatus  \
# 0               3         1        2                4              1
# 1               3         1        8                1              1
# 2               3         2        7                4              0
# 3               3         2        0                1              1
# 4               3         5        3                1              2
#
#    MonthlyIncome  MonthlyRate  NumCompaniesWorked  Over18  OverTime  \
# 0           2596         5099                   1       0         1
# 1           2899        10778                   1       0         0
# 2           4627        16495                   0       0         0
# 3           5347        13384                   3       0         0
# 4          19033        19805                   1       0         1
#
#    PercentSalaryHike  PerformanceRating  RelationshipSatisfaction  \
# 0                 13                  3                         2
# 1                 17                  3                         4
# 2                 17                  3                         4
# 3                 14                  3                         3
# 4                 13                  3                         3
#
#    StandardHours  StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  \
# 0             80                 1                 10                      2
# 1             80                 1                  4                      3
# 2             80                 2                  4                      3
# 3             80                 0                 15                      1
# 4             80                 0                 31                      0
#
#    WorkLifeBalance  YearsAtCompany  YearsInCurrentRole  \
# 0                3              10                   0
# 1                3               4                   2
# 2                3               3                   2
# 3                1               6                   0
# 4                3              31                  14
#
#    YearsSinceLastPromotion  YearsWithCurrManager  Attrition  \
# 0                        7                     8          0
# 1                        0                     3          0
# 2                        1                     2          0
# 3                        0                     2          0
# 4                        4                    10          1
#
#    Count_BusinessTravel  Count_Department  Count_EducationField  Count_Gender  \
# 0                   261              1167                   549          1064
# 1                  1290               471                    82          1064
# 2                  1290               471                   152          1064
# 3                  1290              1167                   549           613
# 4                  1290              1167                   549           613
#
#    Count_JobRole  Count_MaritalStatus
# 0            334                  773
# 1             77                  773
# 2            355                  327
# 3            155                  773
# 4            111                  577

# %%
test.head()
# Out:
#    Age  BusinessTravel  DailyRate  Department  DistanceFromHome  Education  \
# 0   19               0        992           1                 1          1
# 1   45               2       1136           2                 4          4
# 2   37               2        155           1                13          3
# 3   32               2        688           1                 1          4
# 4   29               1        464           1                 9          1
#
#    EducationField  EmployeeCount  EnvironmentSatisfaction  Gender  HourlyRate  \
# 0               3              1                        4       1          43
# 1               2              1                        3       1          67
# 2               1              1                        4       1          41
# 3               1              1                        3       1          89
# 4               1              1                        3       1          79
#
#    JobInvolvement  JobLevel  JobRole  JobSatisfaction  MaritalStatus  \
# 0               3         1        2                3              2
# 1               3         2        7                1              0
# 2               3         1        6                4              0
# 3               2         2        0                3              2
# 4               3         1        2                4              2
#
#    MonthlyIncome  MonthlyRate  NumCompaniesWorked  Over18  OverTime  \
# 0           2318        17778                   1       0         0
# 1           5486        12421                   6       0         1
# 2           2741        23577                   4       0         1
# 3           5228        20364                   1       0         0
# 4           1223        15178                   1       0         0
#
#    PercentSalaryHike  PerformanceRating  RelationshipSatisfaction  \
# 0                 12                  3                         4
# 1                 12                  3                         3
# 2                 13                  3                         2
# 3                 13                  3                         3
# 4                 14                  3                         1
#
#    StandardHours  StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  \
# 0             80                 0                  1                      2
# 1             80                 1                  7                      3
# 2             80                 2                 13                      2
# 3             80                 0                 14                      2
# 4             80                 0                  1                      5
#
#    WorkLifeBalance  YearsAtCompany  YearsInCurrentRole  \
# 0                2               1                   0
# 1                3               2                   2
# 2                2               7                   7
# 3                2              14                  10
# 4                3               1                   0
#
#    YearsSinceLastPromotion  YearsWithCurrManager  Count_BusinessTravel  \
# 0                        0                     0                   108
# 1                        2                     2                   799
# 2                        1                     7                   799
# 3                       11                     8                   799
# 4                        0                     0                   212
#
#    Count_Department  Count_EducationField  Count_Gender  Count_JobRole  \
# 0               777                   345           690            230
# 1               306                   102           690            240
# 2               777                   519           690            230
# 3               777                   519           690            112
# 4               777                   519           690            230
#
#    Count_MaritalStatus
# 0                  394
# 1                  201
# 2                  201
# 3                  394
# 4                  394

# %% [markdown]
# Now we have transform categorical variables to numerical using label encoder so the next thing we are going to do is to select our X and Y variable and then build a model.

# %%
X = train.drop(["Attrition", "Over18", "EmployeeCount", "StandardHours"], axis=1)
y = train.Attrition
test = test.drop(["Over18", "EmployeeCount", "StandardHours"], axis=1)

# %%
X.shape, test.shape
# Out:
# ((1677, 36), (1119, 36))

# %% [markdown]
# # Modeling

# %%
params = {
    "objective": "Logloss",
    "colsample_bylevel": 0.08383650771477613,
    "depth": 11,
    "boosting_type": "Ordered",
    "bootstrap_type": "Bayesian",
    "bagging_temperature": 0.01880446878521802,
}

# %%
best_para = {
    "objective": "Logloss",
    "learning_rate": 0.1,
    "colsample_bylevel": 0.03821738692876321,
    "depth": 4,
    "boosting_type": "Plain",
    "bootstrap_type": "Bayesian",
    "n_estimators": 2026,
    "bagging_temperature": 7.549705377998899,
}

# %%
# random params but feel free to tune
catboost_params = {
    "loss_function": "CrossEntropy",
    "learning_rate": 0.76,
    "l2_leaf_reg": 0.014,
    "colsample_bylevel": 0.06,
    "depth": 1,
    "boosting_type": "Plain",
    "bootstrap_type": "Bernoulli",
    "min_data_in_leaf": 18,
    "one_hot_max_size": 14,
    "subsample": 0.99,
}

# %%
# %%time
kf = RepeatedStratifiedKFold(n_splits=8, n_repeats=5, random_state=42)

preds = []
scores = []
feature_importance_df = pd.DataFrame()

for fold, (idx_train, idx_valid) in enumerate(kf.split(X, y)):
    X_train, y_train = X.iloc[idx_train], y.iloc[idx_train]
    X_valid, y_valid = X.iloc[idx_valid], y.iloc[idx_valid]

    model = CatBoostClassifier(
        **catboost_params,
        use_best_model=True,
    )

    model.fit(
        X_train,
        y_train,
        eval_set=[(X_valid, y_valid)],
        verbose=False,
        # early_stopping_rounds=400,
    )

    pred_valid = model.predict_proba(X_valid)[:, 1]
    fpr, tpr, _ = metrics.roc_curve(y_valid, pred_valid)
    score = metrics.auc(fpr, tpr)
    scores.append(score)

    fold_importance_df = pd.DataFrame()
    fold_importance_df["Feature"] = X.columns
    fold_importance_df["importance"] = model.feature_importances_
    fold_importance_df["fold"] = fold + 1
    feature_importance_df = pd.concat(
        [feature_importance_df, fold_importance_df], axis=0
    )

    print(f"Fold: {fold + 1} Score: {score}" "\n")
    print("||" * 40, "\n")

    test_preds = model.predict_proba(test)[:, 1]
    preds.append(test_preds)

print(f"Overall Validation Score: {np.mean(scores)}")
# Out:
# Fold: 1 Score: 0.7645405405405405
#
# ||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
#
# Fold: 2 Score: 0.8508108108108108
#
# ||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
#
# Fold: 3 Score: 0.8240000000000001
#
# ||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
#
# Fold: 4 Score: 0.8188108108108108
#
# ||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
#
# Fold: 5 Score: 0.8356756756756757
#
# ||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
#
# Fold: 6 Score: 0.8219565217391305
#
# ||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
#
# Fold: 7 Score: 0.9113043478260869
#
# ||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
#
# Fold: 8 Score: 0.8597826086956522
#
# ||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
#
# Fold: 9 Score: 0.8480000000000001
#
# ||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
#
# Fold: 10 Score: 0.8523243243243244
#
# ||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
#
# Fold: 11 Score: 0.825945945945946
#
# ||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
#
# Fold: 12 Score: 0.8629189189189189
#
# ||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
#
# Fold: 13 Score: 0.8393513513513513
#
# ||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
#
# Fold: 14 Score: 0.9010869565217391
#
# ||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
#
# Fold: 15 Score: 0.8600000000000001
#
# ||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
#
# Fold: 16 Score: 0.8217391304347826
#
# ||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
#
# Fold: 17 Score: 0.7848648648648648
#
# ||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
#
# Fold: 18 Score: 0.8797837837837837
#
# ||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
#
# Fold: 19 Score: 0.8910270270270271
#
# ||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
#
# Fold: 20 Score: 0.8227027027027026
#
# ||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
#
# Fold: 21 Score: 0.890162162162162
#
# ||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
#
# Fold: 22 Score: 0.8997826086956521
#
# ||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
#
# Fold: 23 Score: 0.857608695652174
#
# ||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
#
# Fold: 24 Score: 0.8178260869565217
#
# ||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
#
# Fold: 25 Score: 0.8305945945945946
#
# ||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
#
# Fold: 26 Score: 0.8038918918918919
#
# ||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
#
# Fold: 27 Score: 0.8012972972972974
#
# ||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
#
# Fold: 28 Score: 0.8261621621621621
#
# ||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
#
# Fold: 29 Score: 0.8542702702702704
#
# ||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
#
# Fold: 30 Score: 0.8591304347826086
#
# ||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
#
# Fold: 31 Score: 0.9158695652173914
#
# ||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
#
# Fold: 32 Score: 0.8593478260869565
#
# ||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
#
# Fold: 33 Score: 0.8497297297297297
#
# ||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
#
# Fold: 34 Score: 0.9007567567567567
#
# ||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
#
# Fold: 35 Score: 0.8572972972972973
#
# ||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
#
# Fold: 36 Score: 0.8523243243243243
#
# ||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
#
# Fold: 37 Score: 0.7465945945945947
#
# ||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
#
# Fold: 38 Score: 0.8880434782608695
#
# ||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
#
# Fold: 39 Score: 0.931304347826087
#
# ||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
#
# Fold: 40 Score: 0.8006521739130436
#
# ||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
#
# Overall Validation Score: 0.8479818155111631
# CPU times: user 1min 6s, sys: 27.3 s, total: 1min 34s
# Wall time: 15 s

# %%
cols = (
    feature_importance_df[["Feature", "importance"]]
    .groupby("Feature")
    .mean()
    .sort_values(by="importance", ascending=False)[:107]
    .index
)
best_features = feature_importance_df.loc[feature_importance_df.Feature.isin(cols)]

plt.figure(figsize=(14, 28))
sns.barplot(
    x="importance",
    y="Feature",
    data=best_features.sort_values(by="importance", ascending=False),
)
plt.title("Features importance (averaged/folds)")
plt.tight_layout()
plt.savefig("FI.png")

# %%
ss.head()
# Out:
#      id  Attrition
# 0  1677   0.119261
# 1  1678   0.119261
# 2  1679   0.119261
# 3  1680   0.119261
# 4  1681   0.119261

# %% [markdown]
# ## Submission

# %%
predictions = np.mean(np.column_stack(preds), axis=1)

ss["Attrition"] = predictions
ss.to_csv("./cb.csv", index=False)
ss.head()
# Out:
#      id  Attrition
# 0  1677   0.154039
# 1  1678   0.058633
# 2  1679   0.030789
# 3  1680   0.078158
# 4  1681   0.535613

# %% [markdown]
# ## Hyperparameter turning

# %%
import catboost as cb
import optuna
from optuna.integration import CatBoostPruningCallback
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split


def objective(trial: optuna.Trial) -> float:
    train_x, valid_x, train_y, valid_y = train_test_split(X, y, test_size=0.25)

    param = {
        "objective": trial.suggest_categorical(
            "objective", ["Logloss", "CrossEntropy"]
        ),
        "learning_rate": trial.suggest_categorical(
            "learning_rate", [0.006, 0.008, 0.01, 0.014, 0.017, 0.02, 0.1]
        ),
        "colsample_bylevel": trial.suggest_float(
            "colsample_bylevel", 0.01, 0.1, log=True
        ),
        "depth": trial.suggest_int("depth", 1, 12),
        "boosting_type": trial.suggest_categorical(
            "boosting_type", ["Ordered", "Plain"]
        ),
        "bootstrap_type": trial.suggest_categorical(
            "bootstrap_type", ["Bayesian", "Bernoulli", "MVS"]
        ),
        "used_ram_limit": "3gb",
        "eval_metric": "Accuracy",
        "n_estimators": trial.suggest_int("n_estimators", 1, 10000),
    }

    if param["bootstrap_type"] == "Bayesian":
        param["bagging_temperature"] = trial.suggest_float("bagging_temperature", 0, 10)
    elif param["bootstrap_type"] == "Bernoulli":
        param["subsample"] = trial.suggest_float("subsample", 0.1, 1, log=True)

    gbm = cb.CatBoostClassifier(**param)

    pruning_callback = CatBoostPruningCallback(trial, "Accuracy")
    gbm.fit(
        train_x,
        train_y,
        eval_set=[(valid_x, valid_y)],
        verbose=0,
        early_stopping_rounds=100,
        callbacks=[pruning_callback],
    )

    # evoke pruning manually.
    pruning_callback.check_pruned()

    preds = gbm.predict(valid_x)
    pred_labels = np.rint(preds)
    accuracy = accuracy_score(valid_y, pred_labels)

    return accuracy


if __name__ == "__main__":
    study = optuna.create_study(
        pruner=optuna.pruners.MedianPruner(n_warmup_steps=5), direction="maximize"
    )
    study.optimize(objective, n_trials=100, timeout=600)

    print("Number of finished trials: {}".format(len(study.trials)))

    print("Best trial:")
    trial = study.best_trial

    print("  Value: {}".format(trial.value))

    print("  Params: ")
    for key, value in trial.params.items():
        print("    {}: {}".format(key, value))
# Out:
# [I 2023-01-18 00:48:08,270] A new study created in memory with name: no-name-e8f9d87b-55b2-49a0-99ad-950d3ff17890
# [I 2023-01-18 00:48:08,404] Trial 0 finished with value: 0.8761904761904762 and parameters: {'objective': 'Logloss', 'learning_rate': 0.014, 'colsample_bylevel': 0.021883568494095316, 'depth': 4, 'boosting_type': 'Ordered', 'bootstrap_type': 'MVS', 'n_estimators': 2888}. Best is trial 0 with value: 0.8761904761904762.
# [I 2023-01-18 00:48:08,529] Trial 1 finished with value: 0.8738095238095238 and parameters: {'objective': 'Logloss', 'learning_rate': 0.014, 'colsample_bylevel': 0.06493119780099459, 'depth': 7, 'boosting_type': 'Plain', 'bootstrap_type': 'Bayesian', 'n_estimators': 7763, 'bagging_temperature': 6.579504117487472}. Best is trial 0 with value: 0.8761904761904762.
# [I 2023-01-18 00:48:08,782] Trial 2 finished with value: 0.8976190476190476 and parameters: {'objective': 'Logloss', 'learning_rate': 0.017, 'colsample_bylevel': 0.048465339173031925, 'depth': 11, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bernoulli', 'n_estimators': 2884, 'subsample': 0.22110773241194712}. Best is trial 2 with value: 0.8976190476190476.
# [I 2023-01-18 00:48:08,929] Trial 3 finished with value: 0.9 and parameters: {'objective': 'Logloss', 'learning_rate': 0.014, 'colsample_bylevel': 0.027027622670497718, 'depth': 5, 'boosting_type': 'Ordered', 'bootstrap_type': 'MVS', 'n_estimators': 7996}. Best is trial 3 with value: 0.9.
# [I 2023-01-18 00:48:09,095] Trial 4 finished with value: 0.8928571428571429 and parameters: {'objective': 'CrossEntropy', 'learning_rate': 0.01, 'colsample_bylevel': 0.039555294896720224, 'depth': 4, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bernoulli', 'n_estimators': 8428, 'subsample': 0.27607755031377973}. Best is trial 3 with value: 0.9.
# [I 2023-01-18 00:48:09,122] Trial 5 pruned. Trial was pruned at iteration 5.
# [I 2023-01-18 00:48:09,208] Trial 6 pruned. Trial was pruned at iteration 5.
# [I 2023-01-18 00:48:09,232] Trial 7 pruned. Trial was pruned at iteration 5.
# [I 2023-01-18 00:48:09,253] Trial 8 pruned. Trial was pruned at iteration 5.
# [I 2023-01-18 00:48:09,304] Trial 9 pruned. Trial was pruned at iteration 5.
# [I 2023-01-18 00:48:09,333] Trial 10 pruned. Trial was pruned at iteration 5.
# [I 2023-01-18 00:48:09,365] Trial 11 pruned. Trial was pruned at iteration 5.
# [I 2023-01-18 00:48:09,539] Trial 12 finished with value: 0.8976190476190476 and parameters: {'objective': 'Logloss', 'learning_rate': 0.017, 'colsample_bylevel': 0.03437812895964769, 'depth': 9, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bernoulli', 'n_estimators': 95, 'subsample': 0.12314478654888969}. Best is trial 3 with value: 0.9.
# [I 2023-01-18 00:48:09,565] Trial 13 pruned. Trial was pruned at iteration 5.
# [I 2023-01-18 00:48:09,601] Trial 14 pruned. Trial was pruned at iteration 5.
# [I 2023-01-18 00:48:09,629] Trial 15 pruned. Trial was pruned at iteration 5.
# [I 2023-01-18 00:48:09,659] Trial 16 pruned. Trial was pruned at iteration 5.
# [I 2023-01-18 00:48:09,696] Trial 17 pruned. Trial was pruned at iteration 5.
# [I 2023-01-18 00:48:09,727] Trial 18 pruned. Trial was pruned at iteration 5.
# [I 2023-01-18 00:48:09,763] Trial 19 pruned. Trial was pruned at iteration 5.
# [I 2023-01-18 00:48:09,794] Trial 20 pruned. Trial was pruned at iteration 5.
# [I 2023-01-18 00:48:09,834] Trial 21 pruned. Trial was pruned at iteration 5.
# [I 2023-01-18 00:48:09,937] Trial 22 finished with value: 0.9047619047619048 and parameters: {'objective': 'Logloss', 'learning_rate': 0.017, 'colsample_bylevel': 0.02846838092381253, 'depth': 10, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bernoulli', 'n_estimators': 46, 'subsample': 0.16827014253550668}. Best is trial 22 with value: 0.9047619047619048.
# [I 2023-01-18 00:48:09,973] Trial 23 pruned. Trial was pruned at iteration 5.
# [I 2023-01-18 00:48:10,119] Trial 24 finished with value: 0.9095238095238095 and parameters: {'objective': 'Logloss', 'learning_rate': 0.017, 'colsample_bylevel': 0.02101746231774774, 'depth': 11, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bernoulli', 'n_estimators': 3050, 'subsample': 0.1984886969390642}. Best is trial 24 with value: 0.9095238095238095.
# [I 2023-01-18 00:48:10,148] Trial 25 pruned. Trial was pruned at iteration 5.
# [I 2023-01-18 00:48:10,180] Trial 26 pruned. Trial was pruned at iteration 5.
# [I 2023-01-18 00:48:10,211] Trial 27 pruned. Trial was pruned at iteration 5.
# [I 2023-01-18 00:48:10,251] Trial 28 pruned. Trial was pruned at iteration 5.
# [I 2023-01-18 00:48:10,285] Trial 29 pruned. Trial was pruned at iteration 5.
# [I 2023-01-18 00:48:10,318] Trial 30 pruned. Trial was pruned at iteration 5.
# [I 2023-01-18 00:48:10,352] Trial 31 pruned. Trial was pruned at iteration 5.
# [I 2023-01-18 00:48:10,389] Trial 32 pruned. Trial was pruned at iteration 5.
# [I 2023-01-18 00:48:10,418] Trial 33 pruned. Trial was pruned at iteration 5.
# [I 2023-01-18 00:48:10,520] Trial 34 pruned. Trial was pruned at iteration 5.
# [I 2023-01-18 00:48:10,560] Trial 35 pruned. Trial was pruned at iteration 5.
# [I 2023-01-18 00:48:10,590] Trial 36 pruned. Trial was pruned at iteration 5.
# [I 2023-01-18 00:48:10,620] Trial 37 pruned. Trial was pruned at iteration 5.
# [I 2023-01-18 00:48:10,651] Trial 38 pruned. Trial was pruned at iteration 5.
# [I 2023-01-18 00:48:10,682] Trial 39 pruned. Trial was pruned at iteration 5.
# [I 2023-01-18 00:48:10,714] Trial 40 pruned. Trial was pruned at iteration 5.
# [I 2023-01-18 00:48:10,941] Trial 41 finished with value: 0.8976190476190476 and parameters: {'objective': 'Logloss', 'learning_rate': 0.017, 'colsample_bylevel': 0.0353596927249412, 'depth': 10, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bernoulli', 'n_estimators': 2585, 'subsample': 0.1372943906521679}. Best is trial 24 with value: 0.9095238095238095.
# [I 2023-01-18 00:48:10,976] Trial 42 pruned. Trial was pruned at iteration 5.
# [I 2023-01-18 00:48:11,016] Trial 43 pruned. Trial was pruned at iteration 5.
# [I 2023-01-18 00:48:11,271] Trial 44 finished with value: 0.9071428571428571 and parameters: {'objective': 'Logloss', 'learning_rate': 0.017, 'colsample_bylevel': 0.04794108709140857, 'depth': 10, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bernoulli', 'n_estimators': 2810, 'subsample': 0.24289154763176984}. Best is trial 24 with value: 0.9095238095238095.
# [I 2023-01-18 00:48:11,305] Trial 45 pruned. Trial was pruned at iteration 5.
# [I 2023-01-18 00:48:11,344] Trial 46 pruned. Trial was pruned at iteration 5.
# [I 2023-01-18 00:48:11,377] Trial 47 pruned. Trial was pruned at iteration 5.
# [I 2023-01-18 00:48:11,413] Trial 48 pruned. Trial was pruned at iteration 5.
# [I 2023-01-18 00:48:11,466] Trial 49 pruned. Trial was pruned at iteration 5.
# [I 2023-01-18 00:48:11,497] Trial 50 pruned. Trial was pruned at iteration 5.
# [I 2023-01-18 00:48:11,530] Trial 51 pruned. Trial was pruned at iteration 5.
# [I 2023-01-18 00:48:11,578] Trial 52 pruned. Trial was pruned at iteration 5.
# [I 2023-01-18 00:48:11,635] Trial 53 pruned. Trial was pruned at iteration 5.
# [I 2023-01-18 00:48:11,666] Trial 54 pruned. Trial was pruned at iteration 5.
# [I 2023-01-18 00:48:11,726] Trial 55 finished with value: 0.9095238095238095 and parameters: {'objective': 'Logloss', 'learning_rate': 0.017, 'colsample_bylevel': 0.03694848511203603, 'depth': 8, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bernoulli', 'n_estimators': 18, 'subsample': 0.12467605668400737}. Best is trial 24 with value: 0.9095238095238095.
# [I 2023-01-18 00:48:11,761] Trial 56 pruned. Trial was pruned at iteration 5.
# [I 2023-01-18 00:48:11,793] Trial 57 pruned. Trial was pruned at iteration 5.
# [I 2023-01-18 00:48:11,835] Trial 58 pruned. Trial was pruned at iteration 5.
# [I 2023-01-18 00:48:11,875] Trial 59 pruned. Trial was pruned at iteration 5.
# [I 2023-01-18 00:48:11,912] Trial 60 pruned. Trial was pruned at iteration 5.
# [I 2023-01-18 00:48:11,947] Trial 61 pruned. Trial was pruned at iteration 5.
# [I 2023-01-18 00:48:11,981] Trial 62 pruned. Trial was pruned at iteration 5.
# [I 2023-01-18 00:48:12,020] Trial 63 pruned. Trial was pruned at iteration 5.
# [I 2023-01-18 00:48:12,057] Trial 64 pruned. Trial was pruned at iteration 5.
# [I 2023-01-18 00:48:12,126] Trial 65 pruned. Trial was pruned at iteration 5.
# [I 2023-01-18 00:48:12,178] Trial 66 pruned. Trial was pruned at iteration 5.
# [I 2023-01-18 00:48:12,220] Trial 67 pruned. Trial was pruned at iteration 5.
# [I 2023-01-18 00:48:12,256] Trial 68 pruned. Trial was pruned at iteration 5.
# [I 2023-01-18 00:48:12,299] Trial 69 pruned. Trial was pruned at iteration 5.
# [I 2023-01-18 00:48:12,333] Trial 70 pruned. Trial was pruned at iteration 5.
# [I 2023-01-18 00:48:12,371] Trial 71 pruned. Trial was pruned at iteration 5.
# [I 2023-01-18 00:48:12,413] Trial 72 pruned. Trial was pruned at iteration 5.
# [I 2023-01-18 00:48:12,465] Trial 73 pruned. Trial was pruned at iteration 5.
# [I 2023-01-18 00:48:12,501] Trial 74 pruned. Trial was pruned at iteration 5.
# [I 2023-01-18 00:48:12,535] Trial 75 pruned. Trial was pruned at iteration 5.
# [I 2023-01-18 00:48:12,569] Trial 76 pruned. Trial was pruned at iteration 5.
# [I 2023-01-18 00:48:12,605] Trial 77 pruned. Trial was pruned at iteration 5.
# [I 2023-01-18 00:48:12,637] Trial 78 pruned. Trial was pruned at iteration 5.
# [I 2023-01-18 00:48:12,685] Trial 79 pruned. Trial was pruned at iteration 5.
# [I 2023-01-18 00:48:13,045] Trial 80 finished with value: 0.9071428571428571 and parameters: {'objective': 'Logloss', 'learning_rate': 0.008, 'colsample_bylevel': 0.053915941197461216, 'depth': 10, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bernoulli', 'n_estimators': 307, 'subsample': 0.16215758865352986}. Best is trial 24 with value: 0.9095238095238095.
# [I 2023-01-18 00:48:13,351] Trial 81 finished with value: 0.9 and parameters: {'objective': 'Logloss', 'learning_rate': 0.008, 'colsample_bylevel': 0.05353735552288309, 'depth': 10, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bernoulli', 'n_estimators': 297, 'subsample': 0.16752630266841065}. Best is trial 24 with value: 0.9095238095238095.
# [I 2023-01-18 00:48:13,416] Trial 82 pruned. Trial was pruned at iteration 5.
# [I 2023-01-18 00:48:13,714] Trial 83 finished with value: 0.9023809523809524 and parameters: {'objective': 'Logloss', 'learning_rate': 0.008, 'colsample_bylevel': 0.049103942459632795, 'depth': 10, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bernoulli', 'n_estimators': 335, 'subsample': 0.250375564657253}. Best is trial 24 with value: 0.9095238095238095.
# [I 2023-01-18 00:48:13,767] Trial 84 pruned. Trial was pruned at iteration 5.
# [I 2023-01-18 00:48:13,816] Trial 85 pruned. Trial was pruned at iteration 5.
# [I 2023-01-18 00:48:13,864] Trial 86 pruned. Trial was pruned at iteration 5.
# [I 2023-01-18 00:48:13,905] Trial 87 pruned. Trial was pruned at iteration 5.
# [I 2023-01-18 00:48:13,952] Trial 88 pruned. Trial was pruned at iteration 5.
# [I 2023-01-18 00:48:14,023] Trial 89 pruned. Trial was pruned at iteration 5.
# [I 2023-01-18 00:48:14,098] Trial 90 pruned. Trial was pruned at iteration 5.
# [I 2023-01-18 00:48:14,165] Trial 91 pruned. Trial was pruned at iteration 5.
# [I 2023-01-18 00:48:14,200] Trial 92 pruned. Trial was pruned at iteration 5.
# [I 2023-01-18 00:48:14,242] Trial 93 pruned. Trial was pruned at iteration 5.
# [I 2023-01-18 00:48:14,290] Trial 94 pruned. Trial was pruned at iteration 5.
# [I 2023-01-18 00:48:14,336] Trial 95 pruned. Trial was pruned at iteration 5.
# [I 2023-01-18 00:48:14,397] Trial 96 pruned. Trial was pruned at iteration 5.
# [I 2023-01-18 00:48:14,452] Trial 97 pruned. Trial was pruned at iteration 5.
# [I 2023-01-18 00:48:14,498] Trial 98 pruned. Trial was pruned at iteration 5.
# [I 2023-01-18 00:48:14,632] Trial 99 finished with value: 0.9 and parameters: {'objective': 'Logloss', 'learning_rate': 0.017, 'colsample_bylevel': 0.030095959429488506, 'depth': 9, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bernoulli', 'n_estimators': 44, 'subsample': 0.11351004229530519}. Best is trial 24 with value: 0.9095238095238095.
# Number of finished trials: 100
# Best trial:
#   Value: 0.9095238095238095
#   Params:
#     objective: Logloss
#     learning_rate: 0.017
#     colsample_bylevel: 0.02101746231774774
#     depth: 11
#     boosting_type: Ordered
#     bootstrap_type: Bernoulli
#     n_estimators: 3050
#     subsample: 0.1984886969390642

# %%
def add(a, b):
    return a + b
print(add(2,8))
# Out:
# 10
